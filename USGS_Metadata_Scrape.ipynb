# %% [markdown]
# # USGS Metadata Scrape

# %%
import pandas as pd
import numpy as np
import requests
import lxml.html as lh
from bs4 import BeautifulSoup

# %% [markdown]
# ## This code pulls stream, spring, and groundwater well gauge site names, site #s, locations, types of parameters, lengths of record, # of samples, etc from USGS Site Web Service within our chosen HUCs:
#
#
#     Accounting Unit 031102 -- Suwannee: The Suwannee River Basin.
#                               Florida, Georgia.
#                                 Area =     9930 sq.mi.
#
#       Cataloging Units  03110201 -- Upper Suwannee.  Florida, Georgia.
#                                       Area =     2720 sq.mi.
#                         03110202 -- Alapaha. Florida, Georgia.
#                                       Area =     1840 sq.mi.
#                         03110203 -- withlacoochee. Florida, Georgia.
#                                       Area =     1510 sq.mi.
#                         03110204 -- Little. Georgia.
#                                       Area =      884 sq.mi.
#                         03110205 -- Lower Suwannee. Florida.
#                                       Area =     1590 sq.mi.
#                         03110206 -- Santa Fe. Florida.
#                                       Area =     1390 sq.mi.

# %% [markdown]
# ### Stream Gauge Sites

# %% [markdown]
# #### The following cell pulls the metadata for all stream gauges within the Suwannee River Basin and creates a pandas dataframe. The first 5 rows of the dataframe are displayed below.

# %%
# URL generated by the USGS Site Web Service. Count number is for # of daily values.
stream_meta_full = pd.read_csv("https://waterservices.usgs.gov/nwis/site/?format=rdb&huc=03110201,03110202,03110203,03110204,03110205,03110206&startDT=1980-01-01&endDT=2021-06-08&outputDataTypeCd=dv&siteType=ST&siteStatus=all", sep='\t',skiprows=(42),header=(0))

stream_meta_df = stream_meta_full
stream_meta_df.drop([0],axis=0,inplace=True)
stream_meta_df.head()
# Out:
#   agency_cd    site_no                                       station_nm  \
# 1      USGS   02314274          SUWANNEE RIVER (AT SILL) NEAR FARGO, GA
# 2      USGS   02314274          SUWANNEE RIVER (AT SILL) NEAR FARGO, GA
# 3      USGS   02314274          SUWANNEE RIVER (AT SILL) NEAR FARGO, GA
# 4      USGS  023142741  NORTH FORK SUWANNEE RIVER AT SILL NEAR FARGO GA
# 5      USGS  023142741  NORTH FORK SUWANNEE RIVER AT SILL NEAR FARGO GA
#
#   site_tp_cd   dec_lat_va   dec_long_va coord_acy_cd dec_coord_datum_cd  \
# 1         ST  30.80410984   -82.4173514            S              NAD83
# 2         ST  30.80410984   -82.4173514            S              NAD83
# 3         ST  30.80410984   -82.4173514            S              NAD83
# 4         ST  30.81633217  -82.41346259            S              NAD83
# 5         ST  30.81633217  -82.41346259            S              NAD83
#
#     alt_va alt_acy_va  ... stat_cd  ts_id loc_web_ds medium_grp_cd  \
# 1      117         .5  ...   00001  26363        NaN           wat
# 2      117         .5  ...   00002  26364        NaN           wat
# 3      117         .5  ...   00003  26365        NaN           wat
# 4   117.00         .5  ...   00006  26369        NaN           wat
# 5   117.00         .5  ...   00001  26366        NaN           wat
#
#   parm_grp_cd   srs_id access_cd  begin_date    end_date count_nu
# 1         NaN  1645423         0  1999-09-30  2003-09-29     1356
# 2         NaN  1645423         0  1999-09-30  2003-09-29     1356
# 3         NaN  1645423         0  1999-09-30  2003-09-29     1384
# 4         NaN  1644459         0  2000-09-30  2001-09-18      354
# 5         NaN  1645423         0  1998-12-02  2003-09-29     1694
#
# [5 rows x 24 columns]

# %% [markdown]
# #### The following cell determines which sites have more than 10 daily values recorded, prints the site numbers, and counts how many sites there are that fit that description.

# %%
stream_meta_df['count_nu'] = stream_meta_df['count_nu'].astype(int)
stream_meta_df = stream_meta_df.loc[stream_meta_df['count_nu'] > 10]
num_sites = stream_meta_df.site_no.unique()
print(num_sites)
len(num_sites)
# Out:
# ['02314274' '023142741' '02314495' '02314500' '02314986' '02315000'
#  '02315005' '02315200' '02315392' '02315500' '02315520' '02315550'
#  '02315626' '02315920' '02316000' '02317500' '02317620' '02317748'
#  '023177483' '02317755' '023177554' '02317797' '02318000' '02318380'
#  '02318500' '02318700' '02319000' '02319300' '02319394' '02319500'
#  '02319800' '02320000' '02320500' '02320700' '02321000' '02321500'
#  '02321898' '02321900' '02321958' '02321975' '02322016' '02322049'
#  '02322050' '02322500' '02322616' '02322700' '02322703' '02322800'
#  '02323000' '02323500' '02323567' '02323590' '02323592' '291652083064100'
#  '291841083070800' '291842083085100' '291930083082800' '302307083101400'
#  '302556082433800' '302623082434200']
# 60

# %% [markdown]
# #### A list of unique parameter codes measured by the stream gauges is generated. Counts of each parameter are shown.

# %%
num_parms = stream_meta_df.parm_cd.unique()
print(num_parms)
stream_meta_df['parm_cd'].value_counts()
# Out:
# ['00060' '00045' '00065' '00010' '00095' '00300' '00400' '99133' '72192'
#  '80154' '80155' '63680' '63160' '72020' '00480' '63158' '72137']
# 00010    95
# 00065    72
# 00095    65
# 00060    55
# 00045    26
# 00480    22
# 72020    10
# 99133     9
# 63160     8
# 00400     6
# 00300     6
# 63680     3
# 72192     2
# 80155     1
# 72137     1
# 63158     1
# 80154     1
# Name: parm_cd, dtype: int64

# %% [markdown]
# #### Parameter codes from the USGS are pulled down from the web and saved as a dataframe. Column headings are changed. The first 5 rows of the table are shown.

# %%
usgs_parm_codes = 'https://nwis.waterdata.usgs.gov/usa/nwis/pmcodes?radio_pm_search=param_group&pm_group=All+--+include+all+parameter+groups&pm_search=&casrn_search=&srsname_search=&format=html_table&show=parameter_group_nm&show=parameter_nm&show=casrn&show=srsname&show=parameter_units'
usgs_parm_codes_req = requests.get(usgs_parm_codes)
usgs_parm_codes_table = pd.read_html(usgs_parm_codes_req.text, match='1', header=0,converters={'Parameter Code': lambda x: str(x)})
usgs_parm_codes_df = usgs_parm_codes_table[0]
usgs_parm_codes_df.rename(columns={'Parameter Code': 'parm_cd', 
                            'Group Name': 'grp_nm', 'Parameter Name/Description':  'parm_desc', 
                            'Parameter Unit': 'parm_unit'}, inplace = True)
usgs_parm_codes_df.head()
# Out:
#   parm_cd       grp_nm                                          parm_desc  \
# 0   00001  Information  Location in cross section, distance from right...
# 1   00002  Information  Location in cross section, distance from right...
# 2   00003  Information                               Sampling depth, feet
# 3   00005  Information  Location in cross section, fraction of total d...
# 4   00008  Information                           Sample accounting number
#
#   CASRN SRSName parm_unit
# 0   NaN     NaN        ft
# 1   NaN     NaN         %
# 2   NaN     NaN        ft
# 3   NaN     NaN         %
# 4   NaN     NaN        nu

# %%
# Use line below to find the name and description of a given parameter code.
#usgs_parm_codes_df.loc[usgs_parm_codes_df['parm_cd']=='00631']

# %% [markdown]
# #### Stream site parameter codes are compared the the USGS master list and a table of the parameters measured at the sites is shown.

# %%
#avail_parms = usgs_parm_codes_df.loc[usgs_parm_codes_df['parm_cd'] == num_parms]
avail_parm_codes_stream = np.where(usgs_parm_codes_df['parm_cd'].isin(num_parms))
avail_parms_stream = usgs_parm_codes_df.iloc[avail_parm_codes_stream]
display(avail_parms_stream)
stream_meta_df['parm_cd'].value_counts()
# Out:
#       parm_cd                         grp_nm  \
# 1646    00010                       Physical
# 1660    00045                       Physical
# 1673    00060                       Physical
# 1677    00065                       Physical
# 1692    00095                       Physical
# 1733    00400                       Physical
# 1739    00480                       Physical
# 1999    63158                       Physical
# 2001    63160                       Physical
# 2008    63680                       Physical
# 2060    72020                       Physical
# 2081    72137                       Physical
# 2112    72192                       Physical
# 2740    00300  Inorganics, Major, Non-metals
# 3421    99133                       Nutrient
# 19101   80154                       Sediment
# 19102   80155                       Sediment
#
#                                                parm_desc      CASRN  \
# 1646                 Temperature, water, degrees Celsius        NaN
# 1660                        Precipitation, total, inches        NaN
# 1673                    Discharge, cubic feet per second        NaN
# 1677                                   Gage height, feet        NaN
# 1692   Specific conductance, water, unfiltered, micro...        NaN
# 1733        pH, water, unfiltered, field, standard units        NaN
# 1739     Salinity, water, unfiltered, parts per thousand        NaN
# 1999   Stream water level elevation above NGVD 1929, ...        NaN
# 2001   Stream water level elevation above NAVD 1988, ...        NaN
# 2008   Turbidity, water, unfiltered, monochrome near ...        NaN
# 2060                     Elevation above NGVD 1929, feet        NaN
# 2081   Discharge, tidally filtered, cubic feet per se...        NaN
# 2112                   Precipitation, cumulative, inches        NaN
# 2740   Dissolved oxygen, water, unfiltered, milligram...  7782-44-7
# 3421   Nitrate plus nitrite, water, in situ, milligra...        NaN
# 19101  Suspended sediment concentration, milligrams p...        NaN
# 19102   Suspended sediment discharge, short tons per day        NaN
#
#                                         SRSName   parm_unit
# 1646                         Temperature, water       deg C
# 1660                              Precipitation          in
# 1673                   Stream flow, mean. daily       ft3/s
# 1677                               Height, gage          ft
# 1692                       Specific conductance  uS/cm @25C
# 1733                                         pH   std units
# 1739                                   Salinity        ppth
# 1999                                        NaN          ft
# 2001                                        NaN          ft
# 2008                                  Turbidity         FNU
# 2060                                        NaN          ft
# 2081                                        NaN       ft3/s
# 2112                              Precipitation          in
# 2740                                     Oxygen        mg/l
# 3421   Inorganic nitrogen (nitrate and nitrite)   mg/l as N
# 19101    Suspended sediment concentration (SSC)        mg/l
# 19102              Suspended sediment discharge    tons/day
# 00010    95
# 00065    72
# 00095    65
# 00060    55
# 00045    26
# 00480    22
# 72020    10
# 99133     9
# 63160     8
# 00400     6
# 00300     6
# 63680     3
# 72192     2
# 80155     1
# 72137     1
# 63158     1
# 80154     1
# Name: parm_cd, dtype: int64

# %% [markdown]
# #### Changing the number within the ' ' below will give a list of the stream sites that measure that parameter. Available codes to choose from are shown in table above.

# %%
display(stream_meta_df.loc[stream_meta_df['parm_cd'] == '00060'])
# Out:
#     agency_cd          site_no  \
# 1        USGS         02314274
# 2        USGS         02314274
# 3        USGS         02314274
# 5        USGS        023142741
# 6        USGS        023142741
# 7        USGS        023142741
# 18       USGS         02314500
# 22       USGS         02314986
# 24       USGS         02315000
# 29       USGS         02315005
# 33       USGS         02315200
# 35       USGS         02315392
# 37       USGS         02315500
# 42       USGS         02315520
# 49       USGS         02315550
# 57       USGS         02315626
# 73       USGS         02315920
# 80       USGS         02316000
# 90       USGS         02317500
# 99       USGS         02317620
# 104      USGS         02317748
# 107      USGS        023177483
# 113      USGS         02317755
# 121      USGS         02317797
# 128      USGS         02318000
# 134      USGS         02318380
# 143      USGS         02318500
# 163      USGS         02318700
# 168      USGS         02319000
# 174      USGS         02319300
# 179      USGS         02319394
# 185      USGS         02319500
# 190      USGS         02319800
# 198      USGS         02320000
# 206      USGS         02320500
# 214      USGS         02320700
# 217      USGS         02321000
# 223      USGS         02321500
# 229      USGS         02321898
# 231      USGS         02321900
# 235      USGS         02321958
# 243      USGS         02321975
# 248      USGS         02322016
# 249      USGS         02322049
# 252      USGS         02322050
# 256      USGS         02322500
# 262      USGS         02322616
# 266      USGS         02322700
# 278      USGS         02322800
# 291      USGS         02323000
# 296      USGS         02323500
# 307      USGS         02323592
# 349      USGS  291841083070800
# 384      USGS  302556082433800
# 386      USGS  302623082434200
#
#                                             station_nm site_tp_cd  \
# 1              SUWANNEE RIVER (AT SILL) NEAR FARGO, GA         ST
# 2              SUWANNEE RIVER (AT SILL) NEAR FARGO, GA         ST
# 3              SUWANNEE RIVER (AT SILL) NEAR FARGO, GA         ST
# 5      NORTH FORK SUWANNEE RIVER AT SILL NEAR FARGO GA         ST
# 6      NORTH FORK SUWANNEE RIVER AT SILL NEAR FARGO GA         ST
# 7      NORTH FORK SUWANNEE RIVER AT SILL NEAR FARGO GA         ST
# 18              SUWANNEE RIVER AT US 441, AT FARGO, GA         ST
# 22                         ROCKY CREEK NR BELMONT,FLA.         ST
# 24                            SUWANNEE R NR BENTON FLA         ST
# 29                       HUNTER CREEK NEAR BELMONT FLA         ST
# 33                    DEEP CREEK NR SUWANNEE VALLEY FL         ST
# 35                  ROBINSON CR NR SUWANNEE VALLEY  FL         ST
# 37               SUWANNEE RIVER AT WHITE SPRINGS, FLA.         ST
# 42                            SWIFT CREEK AT FACIL FLA         ST
# 49              SUWANNEE RIVER AT SUWANNEE SPRINGS FLA         ST
# 57    ALAPAHA RISE ABOVE SW 68TH DRIVE NEAR JASPER, FL         ST
# 73      ALAPAHA RIVER AT GA 125/32 NEAR IRWINVILLE, GA         ST
# 80                      ALAPAHA RIVER NEAR ALAPAHA, GA         ST
# 90                    ALAPAHA RIVER AT STATENVILLE, GA         ST
# 99                     ALAPAHA RIVER NEAR JENNINGS FLA         ST
# 104    WITHLACOOCHEE R AT SKIPPER BR RD, NR BEMISS, GA         ST
# 33          .1  ...   00003   26381                  NaN           wat
# 35          .1  ...   00003   26383                  NaN           wat
# 37          .1  ...   00003   26385                  NaN           wat
# 42          .1  ...   00003   26393                  NaN           wat
# 49          .1  ...   00003   26398                  NaN           wat
# 57         001  ...   00003   26401                  NaN           wat
# 73          .1  ...   00003   36114                  NaN           wat
# 80          .1  ...   00003   36121                  NaN           wat
# 90          .1  ...   00003   36133                  NaN           wat
# 99          .1  ...   00003   26420                  NaN           wat
# 104          5  ...   00003   36141                  NaN           wat
# 107         .1  ...   00003   36145                  NaN           wat
# 113         .1  ...   00003   36147                  NaN           wat
# 121         .1  ...   00003   36161                  NaN           wat
# 128         .1  ...   00003   36170                  NaN           wat
# 134         .1  ...   00003   36180                  NaN           wat
# 143         .1  ...   00003   36183                  NaN           wat
# 163         .1  ...   00003   36194                  NaN           wat
# 168        .01  ...   00003   26422                  NaN           wat
# 174        .01  ...   00003   26428                  NaN           wat
# 179        .01  ...   00003   26452                  NaN           wat
# 185        .01  ...   00003   26454                  NaN           wat
# 190         .1  ...   00003   26476                  NaN           wat
# 198         .1  ...   00003   26497                  NaN           wat
# 206         .1  ...   00003   26522                  NaN           wat
# 214         .1  ...   00003   26529                  NaN           wat
# 217         .1  ...   00003   26540   Tallahasee Records           wat
# 223         .1  ...   00003   26544                  NaN           wat
# 229        NaN  ...   00003   26556                  NaN           wat
# 231        NaN  ...   00003   26557                  NaN           wat
# 235        1.6  ...   00003   26565                  NaN           wat
# 243        1.6  ...   00003   26566                  NaN           wat
# 248         .1  ...   00003   26568  Tallahassee records           wat
# 249        NaN  ...   00003   26570                  NaN           wat
# 252        NaN  ...   00003   26572  Tallahassee records           wat
# 256         .1  ...   00003   26574                  NaN           wat
# 262        NaN  ...   00003   26585                  NaN           wat
# 266        005  ...   00003   26620                  NaN           wat
# 278         .1  ...   00003   26624                  NaN           wat
# 291         .1  ...   00003   26635                  NaN           wat
# 296        .01  ...   00003   26639                  NaN           wat
# 307        NaN  ...   00003   26698                  NaN           wat
# 349        NaN  ...   00001   29671                  NaN           wat
# 384        NaN  ...   00003   30232                  NaN           wat
# 386        NaN  ...   00003   30249                  NaN           wat
#
#     parm_grp_cd   srs_id access_cd  begin_date    end_date count_nu
# 1           NaN  1645423         0  1999-09-30  2003-09-29     1356
# 2           NaN  1645423         0  1999-09-30  2003-09-29     1356
# 3           NaN  1645423         0  1999-09-30  2003-09-29     1384
# 5           NaN  1645423         0  1998-12-02  2003-09-29     1694
# 6           NaN  1645423         0  1998-12-02  2003-09-29     1694
# 7           NaN  1645423         0  1998-10-01  2003-09-29     1783
# 18          NaN  1645423         0  1927-01-28  2021-06-14    32514
# 22          NaN  1645423         0  1976-05-19  1983-02-18     2399
# 24          NaN  1645423         0  1932-01-01  2015-10-04    12986
# 29          NaN  1645423         0  1979-01-17  1989-01-04     3536
# 33          NaN  1645423         0  1976-04-01  1998-09-29     4929
# 35          NaN  1645423         0  1976-04-01  1981-10-09     2018
# 37          NaN  1645423         0  1906-06-01  2021-06-14    35389
spring_meta_df = spring_meta_full
spring_meta_df.drop([0],axis=0,inplace=True)
spring_meta_df.head()
# Out:
#   agency_cd   site_no                               station_nm site_tp_cd  \
# 1      USGS  02315620         HOLTON SPRINGS NEAR FT. UNION,FL         SP
# 2      USGS  02315620         HOLTON SPRINGS NEAR FT. UNION,FL         SP
# 3      USGS  02319302  MADISON BLUE SPRING NR BLUE SPRINGS, FL         SP
# 4      USGS  02319302  MADISON BLUE SPRING NR BLUE SPRINGS, FL         SP
# 5      USGS  02319302  MADISON BLUE SPRING NR BLUE SPRINGS, FL         SP
#
#     dec_lat_va  dec_long_va coord_acy_cd dec_coord_datum_cd alt_va alt_acy_va  \
# 1  30.43771795  -83.0573582            S              NAD83    NaN        NaN
# 2  30.43771795  -83.0573582            S              NAD83    NaN        NaN
# 3  30.48049106  -83.2443097            F              NAD83     48         15
# 4  30.48049106  -83.2443097            F              NAD83     48         15
# 5  30.48049106  -83.2443097            F              NAD83     48         15
#
#    ... stat_cd   ts_id loc_web_ds medium_grp_cd parm_grp_cd    srs_id  \
# 1  ...   00003  175008        NaN           wat         NaN   1645423
# 2  ...   00003   26399        NaN           wat         NaN  17164583
# 3  ...   00001  222461        NaN           wat         NaN   1645597
# 4  ...   00002  222463        NaN           wat         NaN   1645597
# 5  ...   00003  172070        NaN           wat         NaN   1645597
#
#   access_cd  begin_date    end_date count_nu
# 1         0  2015-06-18  2016-09-29      470
# 2         0  2015-06-18  2016-09-29      470
# 3         0  2014-07-09  2021-06-14     1953
# 4         0  2014-07-09  2021-06-14     1953
# 5         0  2014-07-09  2021-06-14     1953
#
# [5 rows x 24 columns]

# %% [markdown]
# #### The following cell determines which sites have more than 10 daily values recorded, prints the site numbers, and counts how many sites there are that fit that description.

# %%
spring_meta_df['count_nu'] = spring_meta_df['count_nu'].astype(int)
spring_meta_df = spring_meta_df.loc[spring_meta_df['count_nu'] > 10]

num_sites = spring_meta_df.site_no.unique()
print(num_sites)
len(num_sites)
# Out:
# ['02315620' '02319302' '02319520' '02319950' '02320250' '02322400'
#  '02322685' '02322687' '02322688' '02322691' '02322694' '02322695'
#  '02322698' '02323502' '02323566']
# 15

# %% [markdown]
# #### A list of unique parameter codes measured by the spring gauges is generated. Counts of each parameter are shown.

# %%
num_parms = spring_meta_df.parm_cd.unique()
print(num_parms)
print(len(num_parms))
spring_meta_df['parm_cd'].value_counts()
# Out:
# ['00060' '00065' '00010' '00095' '00300' '00400' '63160' '99133']
# 8
# 00400    24
# 00095    24
# 00300    24
# 99133    24
# 00010    23
# 00065    15
# 00060    12
# 63160     4
# Name: parm_cd, dtype: int64

# %% [markdown]
# #### Spring site parameter codes are compared the the USGS master list and a table of the parameters measured at the sites is shown.

# %%
avail_parm_codes_spring = np.where(usgs_parm_codes_df['parm_cd'].isin(num_parms))
avail_parms_spring = usgs_parm_codes_df.iloc[avail_parm_codes_spring]
display(avail_parms_spring)
# Out:
#      parm_cd                         grp_nm  \
# 1646   00010                       Physical
# 1673   00060                       Physical
# 1677   00065                       Physical
# 1692   00095                       Physical
# 1733   00400                       Physical
# 2001   63160                       Physical
# 2740   00300  Inorganics, Major, Non-metals
# 3421   99133                       Nutrient
#
#                                               parm_desc      CASRN  \
# 1646                Temperature, water, degrees Celsius        NaN
# 1673                   Discharge, cubic feet per second        NaN
# 1677                                  Gage height, feet        NaN
# 1692  Specific conductance, water, unfiltered, micro...        NaN
# 1733       pH, water, unfiltered, field, standard units        NaN
# 2001  Stream water level elevation above NAVD 1988, ...        NaN
# 2740  Dissolved oxygen, water, unfiltered, milligram...  7782-44-7
# 3421  Nitrate plus nitrite, water, in situ, milligra...        NaN
#
#                                        SRSName   parm_unit
# 1646                        Temperature, water       deg C
# 1673                  Stream flow, mean. daily       ft3/s
# 1677                              Height, gage          ft
# 1692                      Specific conductance  uS/cm @25C
# 1733                                        pH   std units
# 2001                                       NaN          ft
# 2740                                    Oxygen        mg/l
# 3421  Inorganic nitrogen (nitrate and nitrite)   mg/l as N

# %% [markdown]
# #### Changing the number within the ' ' below will give a list of the spring sites that measure that parameter. Available codes to choose from are shown in table above.

# %%
display(spring_meta_df.loc[spring_meta_df['parm_cd'] == '00060'])
# Out:
#     agency_cd   site_no                                         station_nm  \
# 1        USGS  02315620                   HOLTON SPRINGS NEAR FT. UNION,FL
# 6        USGS  02319302            MADISON BLUE SPRING NR BLUE SPRINGS, FL
# 40       USGS  02319950                          BLUE SPRINGS NEAR DELL,FL
# 85       USGS  02322685            ICHETUCKNEE HEAD SPRING NR HILDRETH, FL
# 87       USGS  02322687                  CEDAR HEAD SPRING NR HILDRETH, FL
# 92       USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 107      USGS  02322691            MISSION SPRINGS COMPLEX NR HILDRETH, FL
# 109      USGS  02322694                 DEVIL'S EYE SPRING NR HILDRETH, FL
# 111      USGS  02322695                   MILL POND SPRING NR HILDRETH, FL
# 113      USGS  02322698  ICHETUCKNEE R A DAMPIER'S LANDING NR HILDRETH, FL
# 118      USGS  02323502                      FANNING SPRINGS NR WILCOX FLA
# 136      USGS  02323566                    MANATEE SPRING NR CHIEFLAND FLA
#
#     site_tp_cd   dec_lat_va   dec_long_va coord_acy_cd dec_coord_datum_cd  \
# 1           SP  30.43771795   -83.0573582            S              NAD83
# 6           SP  30.48049106   -83.2443097            F              NAD83
# 40          SP    30.126055   -83.2259712            S              NAD83
# 85          SP  29.98388889   -82.7619444            S              NAD83
# 87          SP  29.98305556  -82.75888889            S              NAD83
# 92          SP   29.9799552    -82.758457            S              NAD83
# 107         SP  29.97583333   -82.7583333            S              NAD83
# 109         SP  29.97333333   -82.7602778            S              NAD83
# 111         SP  29.96638889        -82.76            S              NAD83
# 113         SP  29.96027778   -82.7722222            S              NAD83
# 118         SP   29.5891247   -82.9331797            S              NAD83
# 136         SP   29.4896808    -82.976791            S              NAD83
#
#      alt_va alt_acy_va  ... stat_cd   ts_id loc_web_ds medium_grp_cd  \
# 1       NaN        NaN  ...   00003  175008        NaN           wat
# 6        48         15  ...   00003  174138        NaN           wat
# 40    25.00          5  ...   00003  224525        NaN           wat
# 85    21.76        .01  ...   00003   26587        NaN           wat
# 87    13.83        .01  ...   00003   26589        NaN           wat
# 92    20.31        .01  ...   00003  229570        NaN           wat
# 107    0.51        .01  ...   00003   26612        NaN           wat
# 109   12.50        .01  ...   00003   26614        NaN           wat
# 111   18.76        .01  ...   00003   26616        NaN           wat
# 113    8.62        .01  ...   00003   26618        NaN           wat
# 118     NaN        NaN  ...   00003   26642        NaN           wat
# 136     NaN        NaN  ...   00003  174485        NaN           wat
#
#     parm_grp_cd   srs_id access_cd  begin_date    end_date count_nu
# 1           NaN  1645423         0  2015-06-18  2016-09-29      470
# 6           NaN  1645423         0  2002-04-12  2021-06-14     6698
# 40          NaN  1645423         0  2015-06-17  2021-06-14     2185
# 85          NaN  1645423         0  2002-02-07  2010-06-08     3044
# 87          NaN  1645423         0  2002-02-11  2010-05-22     3023
# 92          NaN  1645423         0  2002-02-05  2021-06-11     6893
# 107         NaN  1645423         0  2002-02-12  2010-05-06     3006
# 109         NaN  1645423         0  2002-02-12  2010-06-09     3040
# 111         NaN  1645423         0  2002-02-14  2010-04-20     2988
# 113         NaN  1645423         0  2002-02-14  2012-09-29     3751
# 118         NaN  1645423         0  2001-05-27  2021-06-14     7190
# 136         NaN  1645423         0  2001-01-25  2021-06-14     7435
#
# [12 rows x 24 columns]

# %% [markdown]
# ### Groundwater Well Sites

# %% [markdown]
# #### The following cell pulls the metadata for all groundwater wells within the Suwannee River Basin and creates a pandas dataframe. The first 5 rows of the dataframe are displayed below.

# %%
gw_meta_full = pd.read_csv("https://waterservices.usgs.gov/nwis/site/?format=rdb&huc=03110201,03110202,03110203,03110204,03110205,03110206&startDT=1980-01-01&endDT=2021-06-09&outputDataTypeCd=gw&siteType=GW,GW-CR,GW-EX,GW-HZ,GW-IW,GW-MW,GW-TH&siteStatus=all", sep='\t',skiprows=(42),header=(0))

gw_meta_df = gw_meta_full
gw_meta_df.drop([0],axis=0,inplace=True)
gw_meta_df.head()
# Out:
#   agency_cd          site_no                               station_nm  \
# 1      USGS  292448083023801                            GP-6 UFA Well
# 2      USGS  292448083023801                            GP-6 UFA Well
# 3      USGS  292448083023801                            GP-6 UFA Well
# 4      USGS  292507082560201  A J MIMMS(121420)SR 347 SW OF CHIEFLAND
# 5      USGS  292507082560201  A J MIMMS(121420)SR 347 SW OF CHIEFLAND
#
#   site_tp_cd   dec_lat_va   dec_long_va coord_acy_cd dec_coord_datum_cd  \
# 1         GW  29.41333333  -83.04388889            S              NAD83
# 2         GW  29.41333333  -83.04388889            S              NAD83
# 3         GW  29.41333333  -83.04388889            S              NAD83
# 4         GW  29.41885004   -82.9337331            S              NAD83
# 5         GW  29.41885004   -82.9337331            S              NAD83
#
#    alt_va alt_acy_va  ... stat_cd ts_id loc_web_ds medium_grp_cd parm_grp_cd  \
# 1       9        4.3  ...     NaN     0        NaN           wat         NaN
# 2       9        4.3  ...     NaN     0        NaN           wat         NaN
# 3       9        4.3  ...     NaN     0        NaN           wat         NaN
# 4   33.00        .01  ...     NaN     0        NaN           wat         NaN
# 5   33.00        .01  ...     NaN     0        NaN           wat         NaN
#
#     srs_id access_cd  begin_date    end_date count_nu
# 1  1642461         0  2009-05-22  2009-05-22        1
# 2  1642461         0  2009-05-22  2009-05-22        1
# 3  1642008         0  2009-05-22  2009-05-22        1
# 4  1642461         0  1986-09-17  2009-05-19       28
# 5  1642461         0  1986-09-17  2009-05-19       28
#
# [5 rows x 24 columns]

# %% [markdown]
# #### The following cell determines which sites have more than 5 groundwater levels recorded, prints the site numbers, and counts how many sites there are that fit that description.

# %%
gw_meta_df['count_nu'] = gw_meta_df['count_nu'].astype(int)
gw_meta_df = gw_meta_df.loc[gw_meta_df['count_nu'] > 10]

num_sites = gw_meta_df.site_no.unique()
print(num_sites)
len(num_sites)
# Out:
# ['292507082560201' '292713082493601' '292831082445101' '292843082514201'
#  '292921082583285' '292935083025402' '292957082593901' '294043082512501'
#  '294306082234701' '294307082020903' '294313082024601' '294330082445001'
#  '294530082232001' '294533082294401' '294538082592601' '294629082181301'
#  '294656082594701' '294721082443001' '294743082543901' '294813082520501'
#  '294839082230701' '294920082044501' '294928082355301' '295105082443301'
#  '295114082393801' '295129082332601' '295130082243001' '295214082482501'
#  '295354082513801' '295615082475401' '295618082440901' '295707082393701'
#  '295737082480801' '295850082140301' '295907082423501' '300010082594201'
#  '300019082355401' '300020082103001' '300101082245201' '300114083025901'
#  '300143082565903' '300249083045301' '300319083065001' '300351083074801'
#  '300400082585001' '300409082415001' '300412083070301' '300443083055701'
#  '300455083051501' '300542082332101' '300612082363101' '300615082130501'
#  '300629082030001' '300635082295901' '300752082473901' '300823083175901'
#  '301031082381001' '301154083111901' '301157083111301' '301239082455201'
#  '301437082324801' '301909082490985' '301921082333401' '302017083111201'
#  '302032082314301' '302100083171001' '302323082493501' '302333083035701'
#  '302450083174885' '302642083065201' '302835082545301' '302847083145401'
#  '303120083050101' '303158082562901' '303312082592101' '303622083050601'
#  '303805083164301' '303851083183001' '303913083140501' '303957083123401'
#  '304034083195201' '304045083175801' '304107083144401' '304108083160201'
#  '304136083095901' '304151083201801' '304206083121601' '304235083191401'
#  '304251083230601' '304304083091001' '304305083172901' '304352083190501'
#  '304400083132601' '304446083400401' '304452083232201' '304504083130501'
#  '304603083160601' '304611083084301' '304614083140401' '304625083180801'
#  '304646083443401' '304706083151001' '304718083262501' '304725083241801'
#  '304814083212101' '304849083170601' '304855083194701' '304942082213801'
#  '304949083165301' '304950083113201' '304952083183901' '305000083213701'
#  '305001083200601' '305017083195401' '305101083181501' '305108083131101'
#  '305118083473601' '305121083161101' '305149083172801' '305202083162801'
#  '305241083154401' '305246083180201' '305250083162401' '305254083162401'
#  '305254083205201' '305257083183501' '305310083125201' '305339083205201'
#  '305340083191701' '305351083175901' '305351083175902' '305352083115201'
#  '305408083183001' '305421083153001' '305421083202901' '305425083121201'
#  '305426083180701' '305448083044201' '305450083150501' '305451083122701'
#  '305451083150501' '305453083142301' '305456083154601' '305504083132001'
#  '305523083200601' '305524083145201' '305542083201501' '305548083155101'
#  '305600083472901' '305602083143101' '305615083143001' '305615083155101'
#  '305626083240101' '305645083162101' '305716083194901' '305721083173101'
#  '305730083115901' '305757083143101' '305811083193401' '305826083252901'
#  '305838083123001' '305901083200001' '305949083261401' '310009083115401'
#  '310118083170701' '310127083122201' '310211083405301' '310221083212201'
#  '310526083443201' '310528083193301' '310609083412401' '310706082155101'
#  '310748083352601' '310813083260301' '310823083375601' '311005083260801'
#  '311006083402001' '311015083321401' '311015083321402' '311040083353801'
#  '311220083330201' '311255083275801' '311302083421701' '311308083353801'
#  '311317083374901' '311427083464201' '311452083400701' '311730083412501'
#  '311845083313901' '311930083390901' '312003083314401' '312021083350101'
#  '312025083401101' '312101083434401' '312127083374701' '312249083503501'
#  '312356083462001' '312405083421401' '312505083382001' '312529083423501'
#  '312623083352401' '312645083522801' '312703083263601' '312711083293101'
#  '312711083293102' '312712082593301' '312758083232401' '312802083370201'
#  '312920083512601' '312949083303201' '313004083371801' '313034083381201'
#  '313039083461001' '313116083342601' '313122083110901' '313122083325101'
#  '313144083335501' '313144083472401' '313146083491601' '313233083502401'
#  '313238083331901' '313435083390101' '313517083494901' '313521083501402'
#  '313630083385001' '313632083323401' '313640083321201' '313822083311901'
#  '313841083155401' '313913083375201' '313950083425401' '314115083351301'
#  '314123083391301' '314254083342001' '314315083224601' '314323083325701'
#  '314418083390501' '314646083310201' '314745083261401' '314847083360301'
#  '315043083401901' '315059083350901' '315314083395501' '315657083273001'
#  '315747083312901']
# 245

# %% [markdown]
# #### A list of unique parameter codes measured by the groundwater sites is generated. Counts of each parameter are shown.

# %%
num_parms = gw_meta_df.parm_cd.unique()
print(num_parms)
print(len(num_parms))
gw_meta_df['parm_cd'].value_counts()
# Out:
# ['62610' '62611' '72019']
# 3
# 72019    245
# 62611    245
# 62610    245
# Name: parm_cd, dtype: int64

# %% [markdown]
# #### Groundwater site parameter codes are compared the the USGS master list and a table of the parameters measured at the sites is shown.

# %%
avail_parm_codes_gw = np.where(usgs_parm_codes_df['parm_cd'].isin(num_parms))
avail_parms_gw = usgs_parm_codes_df.iloc[avail_parm_codes_gw]
display(avail_parms_gw)
# Out:
#      parm_cd    grp_nm                                      parm_desc CASRN  \
# 1950   62610  Physical        Groundwater level above NGVD 1929, feet   NaN
# 1951   62611  Physical        Groundwater level above NAVD 1988, feet   NaN
# 2059   72019  Physical  Depth to water level, feet below land surface   NaN
#
#                                       SRSName parm_unit
# 1950                                      NaN        ft
# 1951                                      NaN        ft
# 2059  Depth to water level below land surface        ft

# %% [markdown]
# #### Changing the number within the ' ' below will give a list of the groundwater sites that measure that parameter. Available codes to choose from are shown in table above.

# %%
display(gw_meta_df.loc[gw_meta_df['parm_cd'] == '62610'])
# Out:
#      agency_cd          site_no                               station_nm  \
# 4         USGS  292507082560201  A J MIMMS(121420)SR 347 SW OF CHIEFLAND
# 7         USGS  292713082493601                H.E.MILLS NR CHIEFLAND,FL
# 10        USGS  292831082445101                                  DOT-27A
# 13        USGS  292843082514201    928251141 11S14E36 DRUMMOND LUMBER CO
# 16        USGS  292921082583285               MANATEE SPRINGS STATE PARK
# ...        ...              ...                                      ...
# 3253      USGS  315043083401901                                   16N006
# 3256      USGS  315059083350901                                   17N003
# 3259      USGS  315314083395501                                   16P004
# 3268      USGS  315657083273001                                   18P001
# 3277      USGS  315747083312901                                   17P005
#
#      site_tp_cd   dec_lat_va   dec_long_va coord_acy_cd dec_coord_datum_cd  \
# 4            GW  29.41885004   -82.9337331            S              NAD83
# 7            GW  29.45385208   -82.8265073            S              NAD83
# 10           GW  29.47552064   -82.7473379            S              NAD83
# 13           GW  29.47885087  -82.86150889            S              NAD83
# 16           GW   29.4886611  -82.97523889            S              NAD83
# ...         ...          ...           ...          ...                ...
# 3253         GW  31.84545527   -83.6718355            F              NAD83
# 3256         GW   31.8499003   -83.5857219            F              NAD83
# 3259         GW   31.8873989   -83.6651687            F              NAD83
# 3268         GW  31.95045496   -83.4576634            U              NAD83
# 3277         GW  31.96323178   -83.5246102            F              NAD83
#
#        alt_va alt_acy_va  ... stat_cd ts_id loc_web_ds medium_grp_cd  \
# 4       33.00        .01  ...     NaN     0        NaN           wat
# 7          31        1.6  ...     NaN     0        NaN           wat
# 10         49        1.6  ...     NaN     0        NaN           wat
# 13      35.00         .1  ...     NaN     0        NaN           wat
# 16         16        .01  ...     NaN     0        NaN           wat
# ...       ...        ...  ...     ...   ...        ...           ...
# 3253      422         10  ...     NaN     0        NaN           wat
# 3256      430         10  ...     NaN     0        NaN           wat
# 3259   390.00          5  ...     NaN     0        NaN           wat
# 3268      367         10  ...     NaN     0        NaN           wat
# 3277      403         10  ...     NaN     0        NaN           wat
#
#      parm_grp_cd   srs_id access_cd  begin_date    end_date count_nu
# 4            NaN  1642461         0  1986-09-17  2009-05-19       28
# 7            NaN  1642461         0  1984-05-15  2009-05-19       39
# 10           NaN  1642461         0  1998-04-29  1999-09-30       18
# 13           NaN  1642461         0  1961-02-08  1990-05-16       72
# 16           NaN  1642461         0  2009-05-22  2021-06-09       60
# ...          ...      ...       ...         ...         ...      ...
# 3253         NaN  1642461         0  1994-03-03  2013-04-24       20
# 3256         NaN  1642461         0  1994-03-10  2021-04-13       18
# 3259         NaN  1642461         0  1977-12-01  1994-11-01       14
# 3268         NaN  1642461         0  1966-02-16  1990-05-18       12
# 3277         NaN  1642461         0  1994-03-11  2019-04-02       16
#
# [245 rows x 24 columns]

# %% [markdown]
# ### All Sites

# %% [markdown]
# #### The cell below concatenates the stream, spring, and gw well metadata into one dataframe.

# %%
usgs_all_sites_df = pd.concat((stream_meta_df,spring_meta_df,gw_meta_df))

# %% [markdown]
# #### The following cells find the unique parameter codes in the concatenated table and then lists them in table format including the number of sites for each parameter.

# %%
num_parms = usgs_all_sites_df.parm_cd.unique()
print(num_parms)
print(len(num_parms))
parm_instance_all = usgs_all_sites_df['parm_cd'].value_counts()
# Out:
# ['00060' '00045' '00065' '00010' '00095' '00300' '00400' '99133' '72192'
#  '80154' '80155' '63680' '63160' '72020' '00480' '63158' '72137' '62610'
#  '62611' '72019']
# 20

# %%
avail_parm_codes_all = np.where(usgs_parm_codes_df['parm_cd'].isin(num_parms))
avail_parms_all = usgs_parm_codes_df.iloc[avail_parm_codes_all]

# %%
avail_parms_count_df = pd.merge(parm_instance_all, avail_parms_all, left_index=True, right_on='parm_cd')
avail_parms_count_df = avail_parms_count_df.rename(columns={'parm_cd_x': 'count_nu'})
avail_parms_count_df = avail_parms_count_df.drop(['parm_cd_y'], axis=1)
display(avail_parms_count_df)
# Out:
#       parm_cd  count_nu                         grp_nm  \
# 2059    72019       245                       Physical
# 1950    62610       245                       Physical
# 1951    62611       245                       Physical
# 1646    00010       118                       Physical
# 1692    00095        89                       Physical
# 1677    00065        87                       Physical
# 1673    00060        67                       Physical
# 3421    99133        33                       Nutrient
# 1733    00400        30                       Physical
# 2740    00300        30  Inorganics, Major, Non-metals
# 1660    00045        26                       Physical
# 1739    00480        22                       Physical
# 2001    63160        12                       Physical
# 2060    72020        10                       Physical
# 2008    63680         3                       Physical
# 2112    72192         2                       Physical
# 1999    63158         1                       Physical
# 19102   80155         1                       Sediment
# 2081    72137         1                       Physical
# 19101   80154         1                       Sediment
#
#                                                parm_desc      CASRN  \
# 2059       Depth to water level, feet below land surface        NaN
# 1950             Groundwater level above NGVD 1929, feet        NaN
# 1951             Groundwater level above NAVD 1988, feet        NaN
# 1646                 Temperature, water, degrees Celsius        NaN
# 1692   Specific conductance, water, unfiltered, micro...        NaN
# 1677                                   Gage height, feet        NaN
# 1673                    Discharge, cubic feet per second        NaN
# 3421   Nitrate plus nitrite, water, in situ, milligra...        NaN
# 1733        pH, water, unfiltered, field, standard units        NaN
# 2740   Dissolved oxygen, water, unfiltered, milligram...  7782-44-7
# 1660                        Precipitation, total, inches        NaN
# 1739     Salinity, water, unfiltered, parts per thousand        NaN
# 2001   Stream water level elevation above NAVD 1988, ...        NaN
# 2060                     Elevation above NGVD 1929, feet        NaN
# 2008   Turbidity, water, unfiltered, monochrome near ...        NaN
# 2112                   Precipitation, cumulative, inches        NaN
# 1999   Stream water level elevation above NGVD 1929, ...        NaN
# 19102   Suspended sediment discharge, short tons per day        NaN
# 2081   Discharge, tidally filtered, cubic feet per se...        NaN
# 19101  Suspended sediment concentration, milligrams p...        NaN
#
#                                         SRSName   parm_unit
# 2059    Depth to water level below land surface          ft
# 1950                                        NaN          ft
# 1951                                        NaN          ft
# 1646                         Temperature, water       deg C
# 1692                       Specific conductance  uS/cm @25C
# 1677                               Height, gage          ft
# 1673                   Stream flow, mean. daily       ft3/s
# 3421   Inorganic nitrogen (nitrate and nitrite)   mg/l as N
# 1733                                         pH   std units
# 2740                                     Oxygen        mg/l
# 1660                              Precipitation          in
# 1739                                   Salinity        ppth
# 2001                                        NaN          ft
# 2060                                        NaN          ft
# 2008                                  Turbidity         FNU
# 2112                              Precipitation          in
# 1999                                        NaN          ft
# 19102              Suspended sediment discharge    tons/day
# 2081                                        NaN       ft3/s
# 19101    Suspended sediment concentration (SSC)        mg/l
