# %% [markdown]
# # USGS Metadata Scrape

# %%
import pandas as pd
import numpy as np
import requests
import lxml.html as lh
from bs4 import BeautifulSoup

# %% [markdown]
# ### Inside the quotations in the box below, input the directory where you have saved the "SuwData" and this script file.

# %%
directory = "C:/Users/robert.taylor/Documents/"

# %% [markdown]
# ## This code pulls stream, spring, and groundwater well gauge site names, site #s, locations, types of parameters, lengths of record, # of samples, etc from USGS Site Web Service within our chosen HUCs:
#
#
#     Accounting Unit 031102 -- Suwannee: The Suwannee River Basin.
#                               Florida, Georgia.
#                                 Area =     9930 sq.mi.
#
#       Cataloging Units  03110201 -- Upper Suwannee.  Florida, Georgia.
#                                       Area =     2720 sq.mi.
#                         03110202 -- Alapaha. Florida, Georgia.
#                                       Area =     1840 sq.mi.
#                         03110203 -- withlacoochee. Florida, Georgia.
#                                       Area =     1510 sq.mi.
#                         03110204 -- Little. Georgia.
#                                       Area =      884 sq.mi.
#                         03110205 -- Lower Suwannee. Florida.
#                                       Area =     1590 sq.mi.
#                         03110206 -- Santa Fe. Florida.
#                                       Area =     1390 sq.mi.

# %% [markdown]
# ### Stream Gauge Sites

# %% [markdown]
# #### The following cell pulls the metadata for all stream gauges within the Suwannee River Basin and creates a pandas dataframe. The first 5 rows of the dataframe are displayed below.

# %%
# URL generated by the USGS Site Web Service. Count number is for # of daily values.
#stream_meta_full = pd.read_csv("https://waterservices.usgs.gov/nwis/site/?format=rdb&huc=03110201,03110202,03110203,03110204,03110205,03110206&startDT=1980-01-01&endDT=2022-01-20&outputDataTypeCd=dv&siteType=ST&siteStatus=all", sep='\t',skiprows=(42),header=(0))
stream_meta_full = pd.read_csv("https://waterservices.usgs.gov/nwis/site/?format=rdb&huc=03110206&startDT=1980-01-01&endDT=2022-01-20&outputDataTypeCd=dv&siteType=ST&siteStatus=all", sep='\t',skiprows=(42),header=(0))
stream_meta_df = stream_meta_full
stream_meta_df.drop([0],axis=0,inplace=True)
display(stream_meta_df)
stream_meta_df.to_csv(directory+'SuwData/SanteFeSites_20220121.csv')
# Out:
#    agency_cd   site_no                        station_nm site_tp_cd  \
# 1       USGS  02320700  SANTA FE RIVER NEAR GRAHAM, FLA.         ST
# 2       USGS  02320700  SANTA FE RIVER NEAR GRAHAM, FLA.         ST
# 3       USGS  02320700  SANTA FE RIVER NEAR GRAHAM, FLA.         ST
# 4       USGS  02321000      NEW RIVER NR LAKE BUTLER FLA         ST
# 5       USGS  02321000      NEW RIVER NR LAKE BUTLER FLA         ST
# ..       ...       ...                               ...        ...
# 70      USGS  02322800    SANTA FE RIVER NR HILDRETH FLA         ST
# 71      USGS  02322800    SANTA FE RIVER NR HILDRETH FLA         ST
# 72      USGS  02322800    SANTA FE RIVER NR HILDRETH FLA         ST
# 73      USGS  02322800    SANTA FE RIVER NR HILDRETH FLA         ST
# 74      USGS  02322800    SANTA FE RIVER NR HILDRETH FLA         ST
#
#      dec_lat_va  dec_long_va coord_acy_cd dec_coord_datum_cd   alt_va  \
# 1   29.84635394  -82.2195493            S              NAD83   103.55
# 2   29.84635394  -82.2195493            S              NAD83   103.55
# 3   29.84635394  -82.2195493            S              NAD83   103.55
# 4    29.9982954  -82.2739992            S              NAD83    83.80
# 5    29.9982954  -82.2739992            S              NAD83    83.80
# ..          ...          ...          ...                ...      ...
# 70  29.91162076  -82.8604033            S              NAD83     3.50
# 71  29.91162076  -82.8604033            S              NAD83     3.50
# 72  29.91162076  -82.8604033            S              NAD83     3.50
# 73  29.91162076  -82.8604033            S              NAD83     3.50
# 74  29.91162076  -82.8604033            S              NAD83     3.50
#
#    alt_acy_va  ... stat_cd   ts_id          loc_web_ds medium_grp_cd  \
# 1          .1  ...   00003   26529                 NaN           wat
# 2          .1  ...   00003   26530                 NaN           wat
# 3          .1  ...   00003  300900                 NaN           wat
# 4          .1  ...   00003   26540  Tallahasee Records           wat
# 5          .1  ...   00003   26541  Tallahasee Records           wat
# ..        ...  ...     ...     ...                 ...           ...
# 70         .1  ...   00003  300905                 NaN           wat
# 71         .1  ...   00003   26623                 NaN           wat
# 72         .1  ...   00001   26625                 NaN           wat
# 73         .1  ...   00002   26626                 NaN           wat
# 74         .1  ...   00003   26627                 NaN           wat
#
#    parm_grp_cd    srs_id access_cd  begin_date    end_date count_nu
# 1          NaN   1645423         0  1957-09-01  2022-01-20    19499
# 2          NaN  17164583         0  1957-08-07  2022-01-20    18334
# 3          NaN   1642503         0  2014-10-01  2022-01-20     2593
# 4          NaN   1645423         0  1950-01-01  2022-01-20    19082
# 5          NaN  17164583         0  1950-01-20  2022-01-20    17817
# ..         ...       ...       ...         ...         ...      ...
# 70         NaN   1642503         0  2014-10-01  2022-01-20     2661
# 71         NaN         0         0  1978-10-01  1979-09-29      352
# 72         NaN    701177         0  2013-07-10  2016-09-30      981
# 73         NaN    701177         0  2013-07-10  2016-09-30      981
# 74         NaN    701177         0  2012-09-27  2016-09-30     1169
#
# [74 rows x 24 columns]

# %% [markdown]
# #### The following cell determines which sites have more than 50 daily values recorded, prints the site numbers, and counts how many sites there are that fit that description.

# %%
stream_meta_df['count_nu'] = stream_meta_df['count_nu'].astype(int)
stream_meta_df = stream_meta_df.loc[stream_meta_df['count_nu'] > 50]
num_sites = stream_meta_df.site_no.unique()
print(num_sites)
len(num_sites)
# Out:
# ['02320700' '02321000' '02321500' '02321898' '02321900' '02321958'
#  '02321975' '02322016' '02322049' '02322050' '02322500' '02322616'
#  '02322700' '02322703' '02322800']
# 15

# %% [markdown]
# #### A list of unique parameter codes measured by the stream gauges is generated. Counts of each parameter are shown.

# %%
num_parms = stream_meta_df.parm_cd.unique()
print(num_parms)
stream_meta_df['parm_cd'].value_counts()
# Out:
# ['00060' '00065' '63160' '00010' '00095' '00045' '99133' '72020']
# 00010    18
# 00095    18
# 00060    14
# 00065    11
# 99133     6
# 63160     5
# 72020     1
# 00045     1
# Name: parm_cd, dtype: int64

# %% [markdown]
# #### Parameter codes from the USGS are pulled down from the web and saved as a dataframe. Column headings are changed. The first 5 rows of the table are shown.

# %%
usgs_parm_codes_df = pd.read_csv(directory + 'SuwData/USGS_All_Parameter_Codes.csv', converters={'parm_cd':lambda x: str(x)})
#usgs_parm_codes_df = usgs_parm_codes[0]
usgs_parm_codes_df.rename(columns={'Parameter Code': 'parm_cd', 
                            'Group Name': 'grp_nm', 'Parameter Name/Description':  'parm_desc', 
                            'Parameter Unit': 'parm_unit'}, inplace = True)
usgs_parm_codes_df
# Out:
#     Unnamed: 0 parm_cd  count_nu                         grp_nm  \
# 0         1646   00010       118                       Physical
# 1         1951   62611        94                       Physical
# 2         2059   72019        94                       Physical
# 3         1950   62610        94                       Physical
# 4         1692   00095        89                       Physical
# 5         1677   00065        87                       Physical
# 6         1673   00060        67                       Physical
# 7         3421   99133        33                       Nutrient
# 8         2740   00300        30  Inorganics, Major, Non-metals
# 9         1733   00400        30                       Physical
# 10        1660   00045        26                       Physical
# 11        1739   00480        22                       Physical
# 12        2001   63160        12                       Physical
# 13        2060   72020        10                       Physical
# 14        2008   63680         3                       Physical
# 15        2112   72192         2                       Physical
# 16       19102   80155         1                       Sediment
# 17        2081   72137         1                       Physical
# 18       19101   80154         1                       Sediment
# 19        1999   63158         1                       Physical
#
#                                             parm_desc      CASRN  \
# 0                 Temperature, water, degrees Celsius        NaN
# 1             Groundwater level above NAVD 1988, feet        NaN
# 2       Depth to water level, feet below land surface        NaN
# 3             Groundwater level above NGVD 1929, feet        NaN
# 4   Specific conductance, water, unfiltered, micro...        NaN
# 5                                   Gage height, feet        NaN
# 6                    Discharge, cubic feet per second        NaN
# 7   Nitrate plus nitrite, water, in situ, milligra...        NaN
# 8   Dissolved oxygen, water, unfiltered, milligram...  7782-44-7
# 9        pH, water, unfiltered, field, standard units        NaN
# 10                       Precipitation, total, inches        NaN
# 11    Salinity, water, unfiltered, parts per thousand        NaN
# 12  Stream water level elevation above NAVD 1988, ...        NaN
# 13                    Elevation above NGVD 1929, feet        NaN
# 14  Turbidity, water, unfiltered, monochrome near ...        NaN
# 15                  Precipitation, cumulative, inches        NaN
# 16   Suspended sediment discharge, short tons per day        NaN
# 17  Discharge, tidally filtered, cubic feet per se...        NaN
# 18  Suspended sediment concentration, milligrams p...        NaN
# 19  Stream water level elevation above NGVD 1929, ...        NaN
#
#                                      SRSName   parm_unit
# 0                         Temperature, water       deg C
# 1                                        NaN          ft
# 2    Depth to water level below land surface          ft
# 3                                        NaN          ft
# 4                       Specific conductance  uS/cm @25C
# 5                               Height, gage          ft
# 6                   Stream flow, mean. daily       ft3/s
# 7   Inorganic nitrogen (nitrate and nitrite)   mg/l as N
# 8                                     Oxygen        mg/l
# 9                                         pH   std units
# 10                             Precipitation          in
# 11                                  Salinity        ppth
# 12                                       NaN          ft
# 13                                       NaN          ft
# 14                                 Turbidity         FNU
# 15                             Precipitation          in
# 16              Suspended sediment discharge    tons/day
# 17                                       NaN       ft3/s
# 18    Suspended sediment concentration (SSC)        mg/l
# 19                                       NaN          ft

# %%
# Use line below to find the name and description of a given parameter code.
usgs_parm_codes_df.loc[usgs_parm_codes_df['parm_cd']=='00060']
# Out:
#    Unnamed: 0 parm_cd  count_nu    grp_nm                         parm_desc  \
# 6        1673   00060        67  Physical  Discharge, cubic feet per second
#
#   CASRN                   SRSName parm_unit
# 6   NaN  Stream flow, mean. daily     ft3/s

# %% [markdown]
# #### Stream site parameter codes are compared the the USGS master list and a table of the parameters measured at the sites is shown.

# %%
avail_parms = usgs_parm_codes_df.loc[usgs_parm_codes_df['parm_cd'] == num_parms]
avail_parm_codes_stream = np.where(usgs_parm_codes_df['parm_cd'].isin(num_parms))
avail_parms_stream = usgs_parm_codes_df.iloc[avail_parm_codes_stream]
display(avail_parms_stream)
stream_meta_df['parm_cd'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-a110ee763c0b> in <module>
# ----> 1 avail_parms = usgs_parm_codes_df.loc[usgs_parm_codes_df['parm_cd'] == num_parms]
#       2 avail_parm_codes_stream = np.where(usgs_parm_codes_df['parm_cd'].isin(num_parms))
#       3 avail_parms_stream = usgs_parm_codes_df.iloc[avail_parm_codes_stream]
#       4 display(avail_parms_stream)
#       5 stream_meta_df['parm_cd'].value_counts()
#
# c:\python\python395\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# c:\python\python395\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      27     @unpack_zerodim_and_defer("__eq__")
#      28     def __eq__(self, other):
# ---> 29         return self._cmp_method(other, operator.eq)
#      30
#      31     @unpack_zerodim_and_defer("__ne__")
#
# c:\python\python395\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    4976         rvalues = extract_array(other, extract_numpy=True)
#    4977
# -> 4978         res_values = ops.comparison_op(lvalues, rvalues, op)
#    4979
#    4980         return self._construct_result(res_values, name=res_name)
#
# c:\python\python395\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     221         #  The ambiguous case is object-dtype.  See GH#27803
#     222         if len(lvalues) != len(rvalues):
# --> 223             raise ValueError(
#     224                 "Lengths must match to compare", lvalues.shape, rvalues.shape
#     225             )
#
# ValueError: ('Lengths must match to compare', (20,), (8,))

# %% [markdown]
# #### Changing the number within the ' ' below will give a list of the stream sites that measure that parameter. Available codes to choose from are shown in table above.

# %%
display(stream_meta_df.loc[stream_meta_df['parm_cd'] == '00060'])
# Out:
#    agency_cd   site_no                                         station_nm  \
# 1       USGS  02320700                   SANTA FE RIVER NEAR GRAHAM, FLA.
# 4       USGS  02321000                       NEW RIVER NR LAKE BUTLER FLA
# 10      USGS  02321500        SANTA FE RIVER AT WORTHINGTON SPRINGS, FLA.
# 16      USGS  02321898            SANTA FE RIVER AT O'LENO STATE PARK FLA
# 18      USGS  02321900                    PARENERS BRANCH NEAR BLAND, FL.
# 22      USGS  02321958   SANTA FE RIVER AT RIVER RISE NR HIGH SPRINGS, FL
# 30      USGS  02321975  SANTA FE RIVER AT US HWY 441 NEAR HIGH SPRINGS...
# 35      USGS  02322016                    BLUES CREEK NEAR GAINSVILLE, FL
# 36      USGS  02322049                    BAD DOG BRANCH NEAR ALACHUA, FL
# 39      USGS  02322050                        SHILOH RUN NEAR ALACHUA, FL
# 43      USGS  02322500               SANTA FE RIVER NEAR FORT WHITE, FLA.
# 49      USGS  02322616                    CANNON CREEK NEAR LAKE CITY, FL
# 53      USGS  02322700              ICHETUCKNEE R @ HWY27 NR HILDRETH, FL
# 65      USGS  02322800                     SANTA FE RIVER NR HILDRETH FLA
#
#    site_tp_cd   dec_lat_va   dec_long_va coord_acy_cd dec_coord_datum_cd  \
# 1          ST  29.84635394   -82.2195493            S              NAD83
# 4          ST   29.9982954   -82.2739992            S              NAD83
# 10         ST   29.9219073   -82.4262246            S              NAD83
# 16         ST  29.92656389   -82.5596472            S              NAD83
# 18         ST  29.90746195   -82.5351166            S              NAD83
# 22         ST   29.8735723  -82.59122849            S              NAD83
# 30         ST  29.85273894   -82.6084508            S              NAD83
# 35         ST  29.72829934   -82.4314979            S              NAD83
# 36         ST  29.82579759   -82.4681682            S              NAD83
# 39         ST  29.81857546   -82.4723348            S              NAD83
# 43         ST  29.84884769   -82.7151204            S              NAD83
# 49         ST  30.15856477    -82.667068            S              NAD83
# 53         ST  29.95273288   -82.7859573            F              NAD83
# 65         ST  29.91162076   -82.8604033            S              NAD83
#
#      alt_va alt_acy_va  ... stat_cd  ts_id           loc_web_ds medium_grp_cd  \
# 1    103.55         .1  ...   00003  26529                  NaN           wat
# 4     83.80         .1  ...   00003  26540   Tallahasee Records           wat
# 10    42.74         .1  ...   00003  26544                  NaN           wat
# 16      NaN        NaN  ...   00003  26556                  NaN           wat
# 18      NaN        NaN  ...   00003  26557                  NaN           wat
# 22       31        1.6  ...   00003  26565                  NaN           wat
# 30       35        1.6  ...   00003  26566                  NaN           wat
# 35      105         .1  ...   00003  26568  Tallahassee records           wat
# 36      NaN        NaN  ...   00003  26570                  NaN           wat
# 39      NaN        NaN  ...   00003  26572  Tallahassee records           wat
# 43    20.86         .1  ...   00003  26574                  NaN           wat
# 49      NaN        NaN  ...   00003  26585                  NaN           wat
# 53    00.00        005  ...   00003  26620                  NaN           wat
# 65     3.50         .1  ...   00003  26624                  NaN           wat
#
#    parm_grp_cd   srs_id access_cd  begin_date    end_date count_nu
# 1          NaN  1645423         0  1957-09-01  2022-01-20    19499
# 4          NaN  1645423         0  1950-01-01  2022-01-20    19082
# 10         NaN  1645423         0  1931-10-01  2022-01-20    32985
# 16         NaN  1645423         0  2011-10-01  2022-01-20     3765
# 18         NaN  1645423         0  1992-09-30  1996-10-17     1479
# 22         NaN  1645423         0  2015-10-01  2022-01-20     2204
# 30         NaN  1645423         0  1992-10-01  2022-01-20     4256
# 35         NaN  1645423         0  1984-06-13  1994-09-29     3761
# 36         NaN  1645423         0  1995-10-01  2006-09-29     3956
# 39         NaN  1645423         0  1983-03-04  1987-10-08     1533
# 43         NaN  1645423         0  1927-10-01  2022-01-20    33595
# 49         NaN  1645423         0  1992-10-01  1998-09-29     2190
# 53         NaN  1645423         0  2002-02-05  2022-01-18     7185
# 65         NaN  1645423         0  2000-11-01  2022-01-20     7024
#
# [14 rows x 24 columns]

# %% [markdown]
# ### Spring Gauge Sites

# %% [markdown]
# #### The following cell pulls the metadata for all spring gauges within the Suwannee River Basin and creates a pandas dataframe. The first 5 rows of the dataframe are displayed below.

# %%
spring_meta_full = pd.read_csv("https://waterservices.usgs.gov/nwis/site/?format=rdb&huc=03110201,03110202,03110203,03110204,03110205,03110206&startDT=1980-01-01&endDT=2022-01-20&outputDataTypeCd=dv&siteType=SP&siteStatus=all", sep='\t',skiprows=(42),header=(0))

spring_meta_df = spring_meta_full
spring_meta_df.drop([0],axis=0,inplace=True)
spring_meta_df.head()
# Out:
#   agency_cd   site_no                               station_nm site_tp_cd  \
# 1      USGS  02315620         HOLTON SPRINGS NEAR FT. UNION,FL         SP
# 2      USGS  02315620         HOLTON SPRINGS NEAR FT. UNION,FL         SP
# 3      USGS  02319302  MADISON BLUE SPRING NR BLUE SPRINGS, FL         SP
# 4      USGS  02319302  MADISON BLUE SPRING NR BLUE SPRINGS, FL         SP
# 5      USGS  02319302  MADISON BLUE SPRING NR BLUE SPRINGS, FL         SP
#
#     dec_lat_va  dec_long_va coord_acy_cd dec_coord_datum_cd alt_va alt_acy_va  \
# 1  30.43771795  -83.0573582            S              NAD83    NaN        NaN
# 2  30.43771795  -83.0573582            S              NAD83    NaN        NaN
# 3  30.48049106  -83.2443097            F              NAD83     48         15
# 4  30.48049106  -83.2443097            F              NAD83     48         15
# 5  30.48049106  -83.2443097            F              NAD83     48         15
#
#    ... stat_cd   ts_id loc_web_ds medium_grp_cd parm_grp_cd    srs_id  \
# 1  ...   00003  175008        NaN           wat         NaN   1645423
# 2  ...   00003   26399        NaN           wat         NaN  17164583
# 3  ...   00001  222461        NaN           wat         NaN   1645597
# 4  ...   00002  222463        NaN           wat         NaN   1645597
# 5  ...   00003  172070        NaN           wat         NaN   1645597
#
#   access_cd  begin_date    end_date count_nu
# 1         0  2015-06-18  2016-09-29      470
# 2         0  2015-06-18  2016-09-29      470
# 3         0  2014-07-09  2022-01-19     2158
# 4         0  2014-07-09  2022-01-19     2158
# 5         0  2014-07-09  2022-01-19     2158
#
# [5 rows x 24 columns]

# %% [markdown]
# #### The following cell determines which sites have more than 10 daily values recorded, prints the site numbers, and counts how many sites there are that fit that description.

# %%
spring_meta_df['count_nu'] = spring_meta_df['count_nu'].astype(int)
spring_meta_df = spring_meta_df.loc[spring_meta_df['count_nu'] > 20]

num_sites = spring_meta_df.site_no.unique()
print(num_sites)
len(num_sites)
# Out:
# ['02315620' '02319302' '02319520' '02319950' '02320250' '02322400'
#  '02322685' '02322687' '02322688' '02322691' '02322694' '02322695'
#  '02322698' '02323502' '02323566']
# 15

# %% [markdown]
# ## Wendy Springs

# %%
searchfor = ['DEVIL', 'HORNSBY', 'ICHETUCKNEE', 'Ichetucknee', 'Blue Hole', 'BLUE HOLE', 'GINNIE', 'JULY']
search_results = spring_meta_df[spring_meta_df['station_nm'].str.startswith(tuple(searchfor))]
display(search_results)
print(search_results['site_no'].value_counts())
LocID = tuple(search_results['station_nm'])
print(LocID)
# Out:
#     agency_cd   site_no                                         station_nm  \
# 70       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 71       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 72       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 73       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 74       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 75       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 76       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 77       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 78       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 79       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 80       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 81       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 82       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 83       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 84       USGS  02322400                  GINNIE SPRING NR HIGH SPRINGS FLA
# 85       USGS  02322685            ICHETUCKNEE HEAD SPRING NR HILDRETH, FL
# 86       USGS  02322685            ICHETUCKNEE HEAD SPRING NR HILDRETH, FL
# 89       USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 90       USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 91       USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 92       USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 93       USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 94       USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 95       USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 96       USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 97       USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 98       USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 99       USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 100      USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 101      USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 102      USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 103      USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 104      USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 105      USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 106      USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 109      USGS  02322694                 DEVIL'S EYE SPRING NR HILDRETH, FL
# 110      USGS  02322694                 DEVIL'S EYE SPRING NR HILDRETH, FL
# 113      USGS  02322698  ICHETUCKNEE R A DAMPIER'S LANDING NR HILDRETH, FL
# 114      USGS  02322698  ICHETUCKNEE R A DAMPIER'S LANDING NR HILDRETH, FL
#
#     site_tp_cd   dec_lat_va  dec_long_va coord_acy_cd dec_coord_datum_cd  \
# 70          SP   29.8360705  -82.7001197            S              NAD83
# 71          SP   29.8360705  -82.7001197            S              NAD83
# 72          SP   29.8360705  -82.7001197            S              NAD83
# 73          SP   29.8360705  -82.7001197            S              NAD83
# 74          SP   29.8360705  -82.7001197            S              NAD83
# 75          SP   29.8360705  -82.7001197            S              NAD83
# 76          SP   29.8360705  -82.7001197            S              NAD83
# 77          SP   29.8360705  -82.7001197            S              NAD83
# 78          SP   29.8360705  -82.7001197            S              NAD83
# 79          SP   29.8360705  -82.7001197            S              NAD83
# 80          SP   29.8360705  -82.7001197            S              NAD83
# 81          SP   29.8360705  -82.7001197            S              NAD83
# 82          SP   29.8360705  -82.7001197            S              NAD83
# 83          SP   29.8360705  -82.7001197            S              NAD83
# 84          SP   29.8360705  -82.7001197            S              NAD83
# 85          SP  29.98388889  -82.7619444            S              NAD83
# 86          SP  29.98388889  -82.7619444            S              NAD83
# 89          SP   29.9799552   -82.758457            S              NAD83
# 90          SP   29.9799552   -82.758457            S              NAD83
# 91          SP   29.9799552   -82.758457            S              NAD83
# 92          SP   29.9799552   -82.758457            S              NAD83
# 93          SP   29.9799552   -82.758457            S              NAD83
# 94          SP   29.9799552   -82.758457            S              NAD83
# 95          SP   29.9799552   -82.758457            S              NAD83
# 96          SP   29.9799552   -82.758457            S              NAD83
# 97          SP   29.9799552   -82.758457            S              NAD83
# 98          SP   29.9799552   -82.758457            S              NAD83
# 99          SP   29.9799552   -82.758457            S              NAD83
# 100         SP   29.9799552   -82.758457            S              NAD83
# 101         SP   29.9799552   -82.758457            S              NAD83
# 102         SP   29.9799552   -82.758457            S              NAD83
# 103         SP   29.9799552   -82.758457            S              NAD83
# 104         SP   29.9799552   -82.758457            S              NAD83
# 105         SP   29.9799552   -82.758457            S              NAD83
# 106         SP   29.9799552   -82.758457            S              NAD83
# 109         SP  29.97333333  -82.7602778            S              NAD83
# 110         SP  29.97333333  -82.7602778            S              NAD83
# 113         SP  29.96027778  -82.7722222            S              NAD83
# 114         SP  29.96027778  -82.7722222            S              NAD83
#
#      alt_va alt_acy_va  ... stat_cd   ts_id loc_web_ds medium_grp_cd  \
# 70      NaN        NaN  ...   00001  242605        NaN           wat
# 71      NaN        NaN  ...   00002  242604        NaN           wat
# 72      NaN        NaN  ...   00003  242602        NaN           wat
# 73      NaN        NaN  ...   00001  242608        NaN           wat
# 74      NaN        NaN  ...   00002  242607        NaN           wat
# 75      NaN        NaN  ...   00003  242609        NaN           wat
# 76      NaN        NaN  ...   00001  242612        NaN           wat
# 77      NaN        NaN  ...   00002  242611        NaN           wat
# 78      NaN        NaN  ...   00003  242613        NaN           wat
# 79      NaN        NaN  ...   00001  242616        NaN           wat
# 80      NaN        NaN  ...   00002  242615        NaN           wat
# 81      NaN        NaN  ...   00003  242617        NaN           wat
# 82      NaN        NaN  ...   00001  260189        NaN           wat
# 83      NaN        NaN  ...   00002  260192        NaN           wat
# 84      NaN        NaN  ...   00003  260191        NaN           wat
# 85    21.76        .01  ...   00003   26587        NaN           wat
# 86    21.76        .01  ...   00003   26586        NaN           wat
# 89    20.31        .01  ...   00001   26592        NaN           wat
# 90    20.31        .01  ...   00002   26593        NaN           wat
# 91    20.31        .01  ...   00003   26594        NaN           wat
# 92    20.31        .01  ...   00003  229570        NaN           wat
# 93    20.31        .01  ...   00003   26590        NaN           wat
# 94    20.31        .01  ...   00001   26595        NaN           wat
# 95    20.31        .01  ...   00002   26596        NaN           wat
# 96    20.31        .01  ...   00003   26597        NaN           wat
# 97    20.31        .01  ...   00001   26601        NaN           wat
# 98    20.31        .01  ...   00002   26602        NaN           wat
# 99    20.31        .01  ...   00003   26603        NaN           wat
# 100   20.31        .01  ...   00001   26598        NaN           wat
# 101   20.31        .01  ...   00002   26599        NaN           wat
# 102   20.31        .01  ...   00008   26600        NaN           wat
# 103   20.31        .01  ...   00003  300904        NaN           wat
# 104   20.31        .01  ...   00001   26604        NaN           wat
# 105   20.31        .01  ...   00002   26605        NaN           wat
# 106   20.31        .01  ...   00003   26606        NaN           wat
# 109   12.50        .01  ...   00003   26614        NaN           wat
# 110   12.50        .01  ...   00003   26613        NaN           wat
# 113    8.62        .01  ...   00003   26618        NaN           wat
# 114    8.62        .01  ...   00003   26617        NaN           wat
#
#     parm_grp_cd    srs_id access_cd  begin_date    end_date count_nu
# 70          NaN   1645597         0  2018-12-14  2022-01-19      735
# 71          NaN   1645597         0  2018-12-14  2022-01-19      735
# 72          NaN  17164583         0  2018-11-09  2022-01-19     1094
# 73          NaN   1646694         0  2018-12-14  2022-01-19      742
# 74          NaN   1646694         0  2018-12-14  2022-01-19      742
# 75          NaN   1646694         0  2018-12-14  2022-01-19      742
# 76          NaN    154302         0  2018-12-14  2022-01-19      624
# 77          NaN    154302         0  2018-12-14  2022-01-19      624
# 78          NaN    154302         0  2018-12-14  2022-01-19      624
# 79          NaN  17028275         0  2018-12-14  2022-01-19      628
# 80          NaN  17028275         0  2018-12-14  2022-01-19      628
# 81          NaN  17028275         0  2018-12-14  2022-01-19      628
# 82          NaN    701177         0  2018-12-14  2022-01-19      717
# 83          NaN    701177         0  2018-12-14  2022-01-19      717
# 84          NaN    701177         0  2018-12-14  2022-01-19      717
# 85          NaN   1645423         0  2002-02-07  2010-06-08     3044
# 86          NaN  17164583         0  2002-02-07  2010-06-08     2963
# 89          NaN   1645597         0  2014-07-01  2021-10-26     2517
# 90          NaN   1645597         0  2014-07-01  2021-10-26     2517
# 91          NaN   1645597         0  2014-07-01  2021-10-26     2517
# 92          NaN   1645423         0  2002-02-05  2022-01-19     7109
# 93          NaN  17164583         0  2002-02-05  2022-01-19     6921
# 94          NaN   1646694         0  2014-07-02  2021-10-26     2486
# 95          NaN   1646694         0  2014-07-02  2021-10-26     2486
# 96          NaN   1646694         0  2014-07-02  2021-10-26     2486
# 97          NaN    154302         0  2014-07-01  2021-10-26     2456
# 98          NaN    154302         0  2014-07-01  2021-10-26     2456
# 99          NaN    154302         0  2014-07-01  2021-10-26     2456
# 100         NaN  17028275         0  2014-07-02  2021-10-26     2427
# 101         NaN  17028275         0  2014-07-02  2021-10-26     2427
# 102         NaN  17028275         0  2014-07-02  2021-10-26     2427
# 103         NaN   1642503         0  2014-10-01  2022-01-19     2600
# 104         NaN    701177         0  2014-07-02  2021-10-26     2174
# 105         NaN    701177         0  2014-07-02  2021-10-26     2173
# 106         NaN    701177         0  2014-07-02  2021-10-26     2174
# 109         NaN   1645423         0  2002-02-12  2010-06-09     3040
# 110         NaN  17164583         0  2002-02-12  2010-06-09     2903
# 113         NaN   1645423         0  2002-02-14  2012-09-29     3751
# 114         NaN  17164583         0  2002-02-15  2012-09-29     3659
#
# [39 rows x 24 columns]
# 02322688    18
# 02322400    15
# 02322698     2
# 02322694     2
# 02322685     2
# Name: site_no, dtype: int64
# ('GINNIE SPRING NR HIGH SPRINGS FLA', 'GINNIE SPRING NR HIGH SPRINGS FLA', 'GINNIE SPRING NR HIGH SPRINGS FLA', 'GINNIE SPRING NR HIGH SPRINGS FLA', 'GINNIE SPRING NR HIGH SPRINGS FLA', 'GINNIE SPRING NR HIGH SPRINGS FLA', 'GINNIE SPRING NR HIGH SPRINGS FLA', 'GINNIE SPRING NR HIGH SPRINGS FLA', 'GINNIE SPRING NR HIGH SPRINGS FLA', 'GINNIE SPRING NR HIGH SPRINGS FLA', 'GINNIE SPRING NR HIGH SPRINGS FLA', 'GINNIE SPRING NR HIGH SPRINGS FLA', 'GINNIE SPRING NR HIGH SPRINGS FLA', 'GINNIE SPRING NR HIGH SPRINGS FLA', 'GINNIE SPRING NR HIGH SPRINGS FLA', 'ICHETUCKNEE HEAD SPRING NR HILDRETH, FL', 'ICHETUCKNEE HEAD SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', 'BLUE HOLE SPRING NR HILDRETH, FL', "DEVIL'S EYE SPRING NR HILDRETH, FL", "DEVIL'S EYE SPRING NR HILDRETH, FL", "ICHETUCKNEE R A DAMPIER'S LANDING NR HILDRETH, FL", "ICHETUCKNEE R A DAMPIER'S LANDING NR HILDRETH, FL")

# %% [markdown]
# #### A list of unique parameter codes measured by the spring gauges is generated. Counts of each parameter are shown.

# %%
num_parms = spring_meta_df.parm_cd.unique()
print(num_parms)
print(len(num_parms))
spring_meta_df['parm_cd'].value_counts()
# Out:
# ['00060' '00065' '00010' '00095' '00300' '00400' '63160' '99133']
# 8
# 00400    24
# 00300    24
# 99133    24
# 00095    24
# 00010    23
# 00065    15
# 00060    12
# 63160     4
# Name: parm_cd, dtype: int64

# %% [markdown]
# #### Spring site parameter codes are compared the the USGS master list and a table of the parameters measured at the sites is shown.

# %%
avail_parm_codes_spring = np.where(usgs_parm_codes_df['parm_cd'].isin(num_parms))
avail_parms_spring = usgs_parm_codes_df.iloc[avail_parm_codes_spring]
display(avail_parms_spring)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python\python395\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'parm_cd'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-104605b9c778> in <module>
# ----> 1 avail_parm_codes_spring = np.where(usgs_parm_codes_df['parm_cd'].isin(num_parms))
#       2 avail_parms_spring = usgs_parm_codes_df.iloc[avail_parm_codes_spring]
#       3 display(avail_parms_spring)
#
# c:\python\python395\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\python\python395\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'parm_cd'

# %% [markdown]
# #### Changing the number within the ' ' below will give a list of the spring sites that measure that parameter. Available codes to choose from are shown in table above.

# %%
display(spring_meta_df.loc[spring_meta_df['parm_cd'] == '00060'])
# Out:
#     agency_cd   site_no                                         station_nm  \
# 1        USGS  02315620                   HOLTON SPRINGS NEAR FT. UNION,FL
# 6        USGS  02319302            MADISON BLUE SPRING NR BLUE SPRINGS, FL
# 40       USGS  02319950                          BLUE SPRINGS NEAR DELL,FL
# 85       USGS  02322685            ICHETUCKNEE HEAD SPRING NR HILDRETH, FL
# 87       USGS  02322687                  CEDAR HEAD SPRING NR HILDRETH, FL
# 92       USGS  02322688                   BLUE HOLE SPRING NR HILDRETH, FL
# 107      USGS  02322691            MISSION SPRINGS COMPLEX NR HILDRETH, FL
# 109      USGS  02322694                 DEVIL'S EYE SPRING NR HILDRETH, FL
# 111      USGS  02322695                   MILL POND SPRING NR HILDRETH, FL
# 113      USGS  02322698  ICHETUCKNEE R A DAMPIER'S LANDING NR HILDRETH, FL
# 118      USGS  02323502                      FANNING SPRINGS NR WILCOX FLA
# 136      USGS  02323566                    MANATEE SPRING NR CHIEFLAND FLA
#
#     site_tp_cd   dec_lat_va   dec_long_va coord_acy_cd dec_coord_datum_cd  \
# 1           SP  30.43771795   -83.0573582            S              NAD83
# 6           SP  30.48049106   -83.2443097            F              NAD83
# 40          SP    30.126055   -83.2259712            S              NAD83
# 85          SP  29.98388889   -82.7619444            S              NAD83
# 87          SP  29.98305556  -82.75888889            S              NAD83
# 92          SP   29.9799552    -82.758457            S              NAD83
# 107         SP  29.97583333   -82.7583333            S              NAD83
# 109         SP  29.97333333   -82.7602778            S              NAD83
# 111         SP  29.96638889        -82.76            S              NAD83
# 113         SP  29.96027778   -82.7722222            S              NAD83
# 118         SP   29.5891247   -82.9331797            S              NAD83
# 136         SP   29.4896808    -82.976791            S              NAD83
#
#      alt_va alt_acy_va  ... stat_cd   ts_id loc_web_ds medium_grp_cd  \
# 1       NaN        NaN  ...   00003  175008        NaN           wat
# 6        48         15  ...   00003  174138        NaN           wat
# 40    25.00          5  ...   00003  224525        NaN           wat
# 85    21.76        .01  ...   00003   26587        NaN           wat
# 87    13.83        .01  ...   00003   26589        NaN           wat
# 92    20.31        .01  ...   00003  229570        NaN           wat
# 107    0.51        .01  ...   00003   26612        NaN           wat
# 109   12.50        .01  ...   00003   26614        NaN           wat
# 111   18.76        .01  ...   00003   26616        NaN           wat
# 113    8.62        .01  ...   00003   26618        NaN           wat
# 118     NaN        NaN  ...   00003   26642        NaN           wat
# 136     NaN        NaN  ...   00003  174485        NaN           wat
#
#     parm_grp_cd   srs_id access_cd  begin_date    end_date count_nu
# 1           NaN  1645423         0  2015-06-18  2016-09-29      470
# 6           NaN  1645423         0  2002-04-12  2022-01-19     6920
# 40          NaN  1645423         0  2015-06-17  2022-01-19     2409
# 85          NaN  1645423         0  2002-02-07  2010-06-08     3044
# 87          NaN  1645423         0  2002-02-11  2010-05-22     3023
# 92          NaN  1645423         0  2002-02-05  2022-01-19     7109
# 107         NaN  1645423         0  2002-02-12  2010-05-06     3006
# 109         NaN  1645423         0  2002-02-12  2010-06-09     3040
# 111         NaN  1645423         0  2002-02-14  2010-04-20     2988
# 113         NaN  1645423         0  2002-02-14  2012-09-29     3751
# 118         NaN  1645423         0  2001-05-27  2022-01-19     7360
# 136         NaN  1645423         0  2001-01-25  2022-01-19     7647
#
# [12 rows x 24 columns]

# %% [markdown]
# ### Groundwater Well Sites

# %% [markdown]
# #### The following cell pulls the metadata for all groundwater wells within the Suwannee River Basin and creates a pandas dataframe. The first 5 rows of the dataframe are displayed below.

# %%
gw_meta_full = pd.read_csv("https://waterservices.usgs.gov/nwis/site/?format=rdb&huc=03110201,03110202,03110203,03110204,03110205,03110206&startDT=1980-01-01&endDT=2021-06-09&outputDataTypeCd=gw&siteType=GW,GW-CR,GW-EX,GW-HZ,GW-IW,GW-MW,GW-TH&siteStatus=all", sep='\t',skiprows=(42),header=(0))

gw_meta_df = gw_meta_full
gw_meta_df.drop([0],axis=0,inplace=True)
gw_meta_df.head()
# Out:
#   agency_cd          site_no                               station_nm  \
# 1      USGS  292448083023801                            GP-6 UFA Well
# 2      USGS  292448083023801                            GP-6 UFA Well
# 3      USGS  292448083023801                            GP-6 UFA Well
# 4      USGS  292507082560201  A J MIMMS(121420)SR 347 SW OF CHIEFLAND
# 5      USGS  292507082560201  A J MIMMS(121420)SR 347 SW OF CHIEFLAND
#
#   site_tp_cd   dec_lat_va   dec_long_va coord_acy_cd dec_coord_datum_cd  \
# 1         GW  29.41333333  -83.04388889            S              NAD83
# 2         GW  29.41333333  -83.04388889            S              NAD83
# 3         GW  29.41333333  -83.04388889            S              NAD83
# 4         GW  29.41885004   -82.9337331            S              NAD83
# 5         GW  29.41885004   -82.9337331            S              NAD83
#
#    alt_va alt_acy_va  ... stat_cd ts_id loc_web_ds medium_grp_cd parm_grp_cd  \
# 1       9        4.3  ...     NaN     0        NaN           wat         NaN
# 2       9        4.3  ...     NaN     0        NaN           wat         NaN
# 3       9        4.3  ...     NaN     0        NaN           wat         NaN
# 4   33.00        .01  ...     NaN     0        NaN           wat         NaN
# 5   33.00        .01  ...     NaN     0        NaN           wat         NaN
#
#     srs_id access_cd  begin_date    end_date count_nu
# 1  1642461         0  2009-05-22  2009-05-22        1
# 2  1642461         0  2009-05-22  2009-05-22        1
# 3  1642008         0  2009-05-22  2009-05-22        1
# 4  1642461         0  1986-09-17  2009-05-19       28
# 5  1642461         0  1986-09-17  2009-05-19       28
#
# [5 rows x 24 columns]

# %% [markdown]
# #### The following cell determines which sites have more than 5 groundwater levels recorded, prints the site numbers, and counts how many sites there are that fit that description.

# %%
gw_meta_df['count_nu'] = gw_meta_df['count_nu'].astype(int)
gw_meta_df = gw_meta_df.loc[gw_meta_df['count_nu'] > 20]

num_sites = gw_meta_df.site_no.unique()
print(num_sites)
len(num_sites)
# Out:
# ['292507082560201' '292713082493601' '292843082514201' '292921082583285'
#  '292935083025402' '294307082020903' '294313082024601' '294330082445001'
#  '294530082232001' '294538082592601' '294721082443001' '294743082543901'
#  '294839082230701' '294928082355301' '295114082393801' '295214082482501'
#  '295618082440901' '295707082393701' '295850082140301' '300020082103001'
#  '300101082245201' '300143082565903' '300400082585001' '300612082363101'
#  '300615082130501' '300823083175901' '301031082381001' '301909082490985'
#  '301921082333401' '302100083171001' '302323082493501' '302450083174885'
#  '302835082545301' '302847083145401' '303158082562901' '303622083050601'
#  '303957083123401' '304251083230601' '304352083190501' '304446083400401'
#  '304504083130501' '304603083160601' '304611083084301' '304614083140401'
#  '304625083180801' '304725083241801' '304814083212101' '304849083170601'
#  '304855083194701' '304942082213801' '304949083165301' '304950083113201'
#  '304952083183901' '305017083195401' '305101083181501' '305121083161101'
#  '305149083172801' '305241083154401' '305246083180201' '305250083162401'
#  '305254083205201' '305257083183501' '305310083125201' '305340083191701'
#  '305351083175902' '305352083115201' '305421083153001' '305421083202901'
#  '305426083180701' '305450083150501' '305451083122701' '305451083150501'
#  '305456083154601' '305602083143101' '305716083194901' '305730083115901'
#  '305757083143101' '305901083200001' '310009083115401' '310609083412401'
#  '310706082155101' '310813083260301' '311220083330201' '312249083503501'
#  '312505083382001' '312529083423501' '312703083263601' '312711083293101'
#  '312711083293102' '312712082593301' '313144083335501' '313146083491601'
#  '313233083502401' '313950083425401']
# 94

# %% [markdown]
# #### A list of unique parameter codes measured by the groundwater sites is generated. Counts of each parameter are shown.

# %%
num_parms = gw_meta_df.parm_cd.unique()
print(num_parms)
print(len(num_parms))
gw_meta_df['parm_cd'].value_counts()
gw_meta_df_unique = gw_meta_df.loc[gw_meta_df['parm_cd'] == '62611']
gw_meta_df_unique.to_csv('C:/Users/robert.taylor/Documents/SuwData/USGS_Wells_df.csv')
# Out:
# ['62610' '62611' '72019']
# 3

# %% [markdown]
# #### Groundwater site parameter codes are compared the the USGS master list and a table of the parameters measured at the sites is shown.

# %%
avail_parm_codes_gw = np.where(usgs_parm_codes_df['parm_cd'].isin(num_parms))
avail_parms_gw = usgs_parm_codes_df.iloc[avail_parm_codes_gw]
display(avail_parms_gw)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python\python395\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'parm_cd'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-0df23b5f1935> in <module>
# ----> 1 avail_parm_codes_gw = np.where(usgs_parm_codes_df['parm_cd'].isin(num_parms))
#       2 avail_parms_gw = usgs_parm_codes_df.iloc[avail_parm_codes_gw]
#       3 display(avail_parms_gw)
#
# c:\python\python395\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\python\python395\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'parm_cd'

# %% [markdown]
# #### Changing the number within the ' ' below will give a list of the groundwater sites that measure that parameter. Available codes to choose from are shown in table above.

# %%
display(gw_meta_df.loc[gw_meta_df['parm_cd'] == '62610'])
# Out:
#      agency_cd          site_no                               station_nm  \
# 4         USGS  292507082560201  A J MIMMS(121420)SR 347 SW OF CHIEFLAND
# 7         USGS  292713082493601                H.E.MILLS NR CHIEFLAND,FL
# 13        USGS  292843082514201    928251141 11S14E36 DRUMMOND LUMBER CO
# 16        USGS  292921082583285               MANATEE SPRINGS STATE PARK
# 19        USGS  292935083025402                     SUNNYVALE TOWER -DUP
# ...        ...              ...                                      ...
# 2296      USGS  312712082593301                                   18K049
# 2563      USGS  313144083335501                                   17L028
# 2569      USGS  313146083491601                                   15L020
# 2608      USGS  313233083502401                                   15L021
# 3004      USGS  313950083425401                                   16M015
#
#      site_tp_cd   dec_lat_va   dec_long_va coord_acy_cd dec_coord_datum_cd  \
# 4            GW  29.41885004   -82.9337331            S              NAD83
# 7            GW  29.45385208   -82.8265073            S              NAD83
# 13           GW  29.47885087  -82.86150889            S              NAD83
# 16           GW   29.4886611  -82.97523889            S              NAD83
# 19           GW  29.49329068   -83.0481822            S              NAD83
# ...         ...          ...           ...          ...                ...
# 2296         GW   31.4535188  -83.49238558            F              NAD83
# 2563         GW       31.529   -83.5652222            1              NAD83
# 2569         GW  31.52962404   -83.8210092            F              NAD83
# 2608         GW   31.5380111   -83.8457944            5              NAD83
# 3004         GW  31.66406885   -83.7148932            F              NAD83
#
#        alt_va alt_acy_va  ... stat_cd ts_id loc_web_ds medium_grp_cd  \
# 4       33.00        .01  ...     NaN     0        NaN           wat
# 7          31        1.6  ...     NaN     0        NaN           wat
# 13      35.00         .1  ...     NaN     0        NaN           wat
# 16         16        .01  ...     NaN     0        NaN           wat
# 19      24.23         .1  ...     NaN     0        NaN           wat
# ...       ...        ...  ...     ...   ...        ...           ...
# 2296   330.00          5  ...     NaN     0        NaN           wat
# 2563    322.3         10  ...     NaN     0        NaN           wat
# 2569      420         10  ...     NaN     0        NaN           wat
# 2608      382          3  ...     NaN     0        NaN           wat
# 3004      417         10  ...     NaN     0        NaN           wat
#
#      parm_grp_cd   srs_id access_cd  begin_date    end_date count_nu
# 4            NaN  1642461         0  1986-09-17  2009-05-19       28
# 7            NaN  1642461         0  1984-05-15  2009-05-19       39
# 13           NaN  1642461         0  1961-02-08  1990-05-16       72
# 16           NaN  1642461         0  2009-05-22  2021-12-15       63
# 19           NaN  1642461         0  1961-02-13  1990-05-22       21
# ...          ...      ...       ...         ...         ...      ...
# 2296         NaN  1642461         0  1985-05-20  2021-12-27      175
# 2563         NaN  1642461         0  2001-11-30  2021-04-13       28
# 2569         NaN  1642461         0  1977-11-16  2021-12-13      288
# 2608         NaN  1642461         0  1972-01-25  2008-11-04       21
# 3004         NaN  1642461         0  1994-02-24  2021-04-14       30
#
# [94 rows x 24 columns]

# %% [markdown]
# ### All Sites

# %% [markdown]
# #### The cell below concatenates the stream, spring, and gw well metadata into one dataframe.

# %%
usgs_all_sites_df = pd.concat((stream_meta_df,spring_meta_df,gw_meta_df))
usgs_all_sites_df.to_csv('C:/Users/robert.taylor/Documents/SuwData/USGS_All_Sites_In_Basin.csv')

# %% [markdown]
# #### The following cells find the unique parameter codes in the concatenated table and then lists them in table format including the number of sites for each parameter.

# %%
num_parms = usgs_all_sites_df.parm_cd.unique()
print(num_parms)
print(len(num_parms))
parm_instance_all = usgs_all_sites_df['parm_cd'].value_counts()
# Out:
# ['00060' '00045' '00065' '00010' '00095' '00300' '00400' '99133' '72192'
#  '80154' '80155' '63680' '63160' '72020' '00480' '63158' '72137' '62610'
#  '62611' '72019']
# 20

# %%
avail_parm_codes_all = np.where(usgs_parm_codes_df['parm_cd'].isin(num_parms))
avail_parms_all = usgs_parm_codes_df.iloc[avail_parm_codes_all]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python\python395\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'parm_cd'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-a660de28db51> in <module>
# ----> 1 avail_parm_codes_all = np.where(usgs_parm_codes_df['parm_cd'].isin(num_parms))
#       2 avail_parms_all = usgs_parm_codes_df.iloc[avail_parm_codes_all]
#
# c:\python\python395\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\python\python395\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'parm_cd'

# %%
avail_parms_count_df = pd.merge(parm_instance_all, avail_parms_all, left_index=True, right_on='parm_cd')
avail_parms_count_df = avail_parms_count_df.rename(columns={'parm_cd_x': 'count_nu'})
avail_parms_count_df = avail_parms_count_df.drop(['parm_cd_y'], axis=1)
display(avail_parms_count_df)
avail_parms_count_df.to_csv('C:/Users/robert.taylor/Documents/SuwData/USGS_All_Parameter_Codes.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-15210312b73d> in <module>
# ----> 1 avail_parms_count_df = pd.merge(parm_instance_all, avail_parms_all, left_index=True, right_on='parm_cd')
#       2 avail_parms_count_df = avail_parms_count_df.rename(columns={'parm_cd_x': 'count_nu'})
#       3 avail_parms_count_df = avail_parms_count_df.drop(['parm_cd_y'], axis=1)
#       4 display(avail_parms_count_df)
#       5 avail_parms_count_df.to_csv('C:/Users/robert.taylor/Documents/SuwData/USGS_All_Parameter_Codes.csv')
#
# NameError: name 'avail_parms_all' is not defined

# %% [markdown]
# ## All Sites within Yellow Polygon

# %%
gw_meta_full_1 = pd.read_csv("https://waterservices.usgs.gov/nwis/site/?format=rdb&huc=03050207,03050208,03050210,03060106,03060108,03060110,03060109,03060202,03060201,03060204&startDT=1980-01-01&endDT=2021-06-27&outputDataTypeCd=gw&siteType=GW,GW-CR,GW-EX,GW-HZ,GW-IW,GW-MW,GW-TH&siteStatus=all", sep='\t',skiprows=(42),header=(0))
gw_meta_full_1.drop([0],axis=0,inplace=True)

gw_meta_full_2 = pd.read_csv("https://waterservices.usgs.gov/nwis/site/?format=rdb&huc=03060203,03070107,03070106,03070102,03070105,03070104,03070202,03070203,03070201,03130006&startDT=1980-01-01&endDT=2021-06-27&outputDataTypeCd=gw&siteType=GW,GW-CR,GW-EX,GW-HZ,GW-IW,GW-MW,GW-TH&siteStatus=all", sep='\t',skiprows=(42),header=(0))
gw_meta_full_2.drop([0],axis=0,inplace=True)

gw_meta_full_3 = pd.read_csv("https://waterservices.usgs.gov/nwis/site/?format=rdb&huc=03110202,03110201,03130007,03110204,03110203,03130009,03130008,03130010,03120002,03070204&startDT=1980-01-01&endDT=2021-06-27&outputDataTypeCd=gw&siteType=GW,GW-CR,GW-EX,GW-HZ,GW-IW,GW-MW,GW-TH&siteStatus=all", sep='\t',skiprows=(42),header=(0))
gw_meta_full_3.drop([0],axis=0,inplace=True)

gw_meta_full_4 = pd.read_csv("https://waterservices.usgs.gov/nwis/site/?format=rdb&huc=03120003,03130013,03120001,03110103,03070205,03110102,03110205,03110206,03080103,03080201&startDT=1980-01-01&endDT=2021-06-27&outputDataTypeCd=gw&siteType=GW,GW-CR,GW-EX,GW-HZ,GW-IW,GW-MW,GW-TH&siteStatus=all", sep='\t',skiprows=(42),header=(0))
gw_meta_full_4.drop([0],axis=0,inplace=True)

gw_meta_full_5 = pd.read_csv("https://waterservices.usgs.gov/nwis/site/?format=rdb&huc=03110101,03080102,03080101,03100208,03100207&startDT=1980-01-01&endDT=2021-06-27&outputDataTypeCd=gw&siteType=GW,GW-CR,GW-EX,GW-HZ,GW-IW,GW-MW,GW-TH&siteStatus=all", sep='\t',skiprows=(42),header=(0))
gw_meta_full_5.drop([0],axis=0,inplace=True)

gw_meta_exp_df = pd.concat((gw_meta_full_1,gw_meta_full_2,gw_meta_full_3,gw_meta_full_4,gw_meta_full_5))

display(gw_meta_exp_df)
# Out:
#      agency_cd          site_no                             station_nm  \
# 1         USGS  304450081333401               33D054 St. Marys GA no.2
# 2         USGS  304450081333401               33D054 St. Marys GA no.2
# 3         USGS  304450081333401               33D054 St. Marys GA no.2
# 4         USGS  310810081323501  33H188 TW-26 Colonels Island, Georgia
# 5         USGS  310810081323501  33H188 TW-26 Colonels Island, Georgia
# ...        ...              ...                                    ...
# 4607      USGS  294640082064501          ROD REESE NR KEYSTONE HEIGHTS
# 4608      USGS  294640082064501          ROD REESE NR KEYSTONE HEIGHTS
# 4609      USGS  294726082101001    94721001  08S21E14 WALDO FIRE DEPT.
# 4610      USGS  294726082101001    94721001  08S21E14 WALDO FIRE DEPT.
# 4611      USGS  294726082101001    94721001  08S21E14 WALDO FIRE DEPT.
#
#      site_tp_cd   dec_lat_va  dec_long_va coord_acy_cd dec_coord_datum_cd  \
# 1            GW  30.74745818  -81.5592637            1              NAD83
# 2            GW  30.74745818  -81.5592637            1              NAD83
# 3            GW  30.74745818  -81.5592637            1              NAD83
# 4            GW  31.13634147  -81.5428798            1              NAD83
# 5            GW  31.13634147  -81.5428798            1              NAD83
# ...         ...          ...          ...          ...                ...
# 4607         GW  29.77802167  -82.1123236            S              NAD83
# 4608         GW  29.77802167  -82.1123236            S              NAD83
# 4609         GW  29.79079934  -82.1692693            S              NAD83
# 4610         GW  29.79079934  -82.1692693            S              NAD83
# 4611         GW  29.79079934  -82.1692693            S              NAD83
#
#        alt_va alt_acy_va  ... stat_cd ts_id loc_web_ds medium_grp_cd  \
# 1          10        2.5  ...     NaN     0        NaN           wat
# 2          10        2.5  ...     NaN     0        NaN           wat
# 3          10        2.5  ...     NaN     0        NaN           wat
# 4        9.37        .01  ...     NaN     0        NaN           wat
# 5        9.37        .01  ...     NaN     0        NaN           wat
# ...       ...        ...  ...     ...   ...        ...           ...
# 4607     167.        .01  ...     NaN     0        NaN           wat
# 4608     167.        .01  ...     NaN     0        NaN           wat
# 4609   159.00        2.5  ...     NaN     0        NaN           wat
# 4610   159.00        2.5  ...     NaN     0        NaN           wat
# 4611   159.00        2.5  ...     NaN     0        NaN           wat
#
#      parm_grp_cd   srs_id access_cd  begin_date    end_date count_nu
# 1            NaN  1642461         0  1993-05-06  2007-05-21       29
# 2            NaN  1642461         0  1993-05-06  2007-05-21       29
# 3            NaN  1642008         0  1993-05-06  2007-05-21       29
# 4            NaN  1642461         0  1978-12-05  2014-12-10      165
# 5            NaN  1642461         0  1978-12-05  2014-12-10      165
# ...          ...      ...       ...         ...         ...      ...
# 4607         NaN  1642461         0  1976-11-15  2007-09-17       34
# 4608         NaN  1642008         0  1976-11-15  2007-09-17       34
# 4609         NaN  1642461         0  1977-05-03  2009-05-18       20
# 4610         NaN  1642461         0  1977-05-03  2009-05-18       20
# 4611         NaN  1642008         0  1977-05-03  2009-05-18       20
#
# [27477 rows x 24 columns]

# %%
gw_meta_exp_df['parm_cd'].value_counts()
# Out:
# 72019    9160
# 62610    9158
# 62611    9158
# 00000       1
# Name: parm_cd, dtype: int64

# %%
gw_meta_exp_df['count_nu'] = gw_meta_exp_df['count_nu'].astype(int)
gw_meta_exp_df = gw_meta_exp_df.loc[gw_meta_exp_df['count_nu'] > 10]

num_sites = gw_meta_exp_df.site_no.unique()
print(num_sites)
len(num_sites)
# Out:
# ['304450081333401' '310810081323501' '310825081294201' ...
#  '294407082262801' '294640082064501' '294726082101001']
# 4090

# %%
gw_meta_exp_df_unique = gw_meta_exp_df.loc[gw_meta_exp_df['parm_cd'] == '62611']
gw_meta_exp_df_unique.to_csv('C:/Users/robert.taylor/Documents/SuwData/USGS_Wells_All_df.csv')
